# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.pipeline import Pipeline
import os
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from pandas import ExcelWriter
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
import openpyxl

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from datetime import datetime
start_time = datetime.now()

# %%
list_level = ['Class', 'Family', 'Genus', 'Order', 'Phylum']
path_local='/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Git_RF/'
path_response=path_local+'response/response_original/'
path_x = path_local+'OTU/normalized_otu/' 
path_soil = path_local+'Env/soil_chemistry/'
path_disease = path_local+'Env/disease_suppression/'
path_field=path_local+'Env/field_information/'
path_alpha=path_local+'OTU/alpha_diversity/'

# %%
cv=RepeatedKFold(n_splits=10,n_repeats=3, random_state=100)

# %%
def process_data(data_train,data_val,cv):  
    x_column_list = data_train.drop(columns=['y_b']).columns  
    percent_label=[round(100*len(np.where(data_train['y_b']==0)[0])/len(data_train)),round(100*len(np.where(data_val['y_b']==0)[0])/len(data_val))]  
    #Classification RF  
    pipeRF = Pipeline([('classifier', [RandomForestClassifier()])])  
    param_grid = [  
    {'classifier' : [RandomForestClassifier()], 
    'classifier__n_estimators': [100, 200],
    'classifier__min_samples_split': [8, 10],
    'classifier__min_samples_leaf': [3, 4, 5],
     'classifier__max_depth': [80, 90],
    'classifier__criterion':('gini','entropy'),  
    'classifier__class_weight':('balanced','auto')}]  
    clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')  
    # Fit on data  
    clf.fit(data_train[x_column_list],data_train['y_b'])  
    best_clf=clf.best_estimator_  
    y_valid=best_clf.predict(data_val[x_column_list])  
    report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)  
    dAll=pd.DataFrame(report_All).transpose()  
    return dAll

# %% [markdown]
# # Alpha diversity

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_alpha_diversity'+'.xlsx', engine='xlsxwriter')   
                for file_folder in os.listdir(path_alpha):  
                    if (file_folder[-4:] != '.csv') & (file_folder != '.DS_Store')& (file_folder != 'Icon\r'):          
                        path = path_alpha+file_folder  
                        os.chdir(path)  
                        file_list = []  
                        tRF=pd.DataFrame()  
                        tcluster=pd.DataFrame()  
                        k=0  
                        for file in os.listdir(path):  
                            if (file[0] != 'Y') & (file[-4:] == '.csv') & (file != '.DS_Store')& (file_folder != 'Icon\r'):  
                                print(file)  
                                file_list.append(file)  
                                data_temp = pd.read_csv(file)  
                                data_temp.drop(columns={'Unnamed: 0'}, inplace=True)  
                                data=pd.merge(response,data_temp,on='Link_ID')   
                                data.drop(columns = 'Link_ID',inplace=True)  
                                data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                                output = process_data(data_train,data_val,cv)  
                                tRF[k]=pd.DataFrame(output['f1-score'].values)         
                                k=k+1  
                        tRF.to_excel(writer, sheet_name=file_folder, index=True)  
                writer.save()
# Out:
# Yield_Plant
# 6.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#      26 data.drop(columns = 'Link_ID',inplace=True)
#      27 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 28 output = process_data(data_train,data_val,cv)
#      29 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      30 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Soil_chemistry

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_soil_chemistry_2'+'.xlsx', engine='xlsxwriter')   
                k=0
                tRF=pd.DataFrame()
                for file in os.listdir(path_soil):  
                    if (file[0] != 's') & (file[-4:] == '.csv') & (file != '.DS_Store')& (file != 'Icon\r'):              
                        print(file)   
                        data_temp = pd.read_csv(path_soil+file)
                        data_temp.drop(columns={'Unnamed: 0'}, inplace=True)  
                        data=pd.merge(response,data_temp,on='Link_ID')   
                        data.drop(columns = 'Link_ID',inplace=True)
                        print(data.shape)
                        data.dropna(inplace=True)
                        print(data.shape)
                        data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                        output = process_data(data_train,data_val,cv)  
                        tRF[k]=pd.DataFrame(output['f1-score'].values)         
                        k=k+1  
                tRF.to_excel(writer, sheet_name=file_folder, index=True)  
        writer.save()
# Out:
# Yield_Plant
# 6.csv
# (219, 13)
# (213, 13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
#      22 print(data.shape)
#      23 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 24 output = process_data(data_train,data_val,cv)
#      25 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      26 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # field_information

# %%
D = pd.read_csv(path_field+'field_information.csv')
D.shape
D.isna().sum()
# Out:
# Column1                             0
# GPS_Lat                            43
# GPS_Lon                            43
# Variety                            16
# Variety2                           13
# Market                             13
# Fumigation1                        16
# Fumigation2                        16
# Soil_type                          31
# Winter_cover                       76
# Cover_crop                         73
# Cover_crop2                       100
# Last_potato_year                   43
# Last_3_year_Rotation_diversity     37
# Rotation_1year                     34
# Rotation_2year                     34
# Rotation_3year                     37
# Rotation_4year                     84
# Rotation_5year                    111
# Rotation_6year                    158
# Rotation_7year                    182
# Irrigated                         149
# Density                           173
# pH_buffer                          89
# pH_1_1                             12
# dtype: int64

# %%
DD = D.drop(columns=['Column1','pH_1_1','GPS_Lat','GPS_Lon','Variety'])
for var in DD:
    print(DD[var].unique().shape[0], 'unique values in', var, '\n',DD[var].unique(), '\n')
    print(DD[var].value_counts())
# Out:
# 8 unique values in Variety2
#  ['Red' 'Russet' 'White' 'Yellow' 'RedLittle' 'YellowLittle' nan 'Mixed']
#
# Russet          115
# Red              60
# White            33
# Yellow           15
# YellowLittle      9
# Mixed             9
# RedLittle         3
# Name: Variety2, dtype: int64
# 5 unique values in Market
#  ['Fresh' 'Processing' 'Chipper' nan 'Mixed']
#
# Fresh         107
# Processing     95
# Chipper        33
# Mixed           9
# Name: Market, dtype: int64
# 3 unique values in Fumigation1
#  ['No' 'Yes' nan]
#
# No     130
# Yes    111
# Name: Fumigation1, dtype: int64
# 4 unique values in Fumigation2
#  ['No' 'Metamsodium' nan 'Chloropicrin']
#
# No              130
# Metamsodium      98
# Chloropicrin     13
# Name: Fumigation2, dtype: int64
# 9 unique values in Soil_type
#  ['Peat' 'Loamy_sand' 'Sand' 'Sandy_loam' nan 'Loamy_fine_sand' 'Silt_loam'
#  'Muck' 'Mucky_loamy_sand']
#
# Loamy_sand          79
# Peat                51
# Silt_loam           32
# Sandy_loam          29
# Sand                18
# Muck                 9
# Loamy_fine_sand      5
# Mucky_loamy_sand     3
# Name: Soil_type, dtype: int64
# 3 unique values in Winter_cover
#  ['Y' nan 'N']
#
# Y    136
# N     45
# Name: Winter_cover, dtype: int64
# 8 unique values in Cover_crop
#  ['Rye' nan 'No' 'Unknown' 'Clover' 'Oats_Hay' 'Clover_Hay' 'Oat_Wheat']
#
# Rye           56
# No            45
# Unknown       27
# Oat_Wheat     26
# Clover        21
# Clover_Hay     6
# Oats_Hay       3
# Name: Cover_crop, dtype: int64
# 7 unique values in Cover_crop2
#  ['Grain' nan 'Unknown' 'Clover' 'No' 'Grain_Grass' 'Clover_Grass']
#
# Grain           82
# Unknown         27
# Clover          21
# No              18
# Clover_Grass     6
# Grain_Grass      3
# Name: Cover_crop2, dtype: int64
# 8 unique values in Last_potato_year
#  [ 4.  2.  6.  7.  3. 10. nan  5.]
#
# 3.0     83
# 4.0     45
# 2.0     38
# 6.0     15
# 10.0    15
# 5.0     12
# 7.0      6
# Name: Last_potato_year, dtype: int64
# 5 unique values in Last_3_year_Rotation_diversity
#  [ 2.  3.  1. nan  4.]
#
# 3.0    127
# 2.0     57
# 1.0     33
# 4.0      3
# Name: Last_3_year_Rotation_diversity, dtype: int64
# 23 unique values in Rotation_1year
#  ['Mustard' 'Fallow' 'Wheat' 'Wild Rice' 'Yellow Pea' 'Kidney Bean'
#  'Alfalfa' 'Corn' nan 'Kidney Bean Bean' 'SweetCorn' 'SeedCorn' 'Heath'
#  'FieldCorn' 'Soybean' 'Clover' 'Oats_Clover' 'Soybean_Potato'
#  'SweetCorn_Soybean' 'Pea' 'Potato_SweetCorn/Soybean' 'SweetCorn_Snapbean'
#  'Snapbean']
#
# Wild Rice                   30
# Kidney Bean                 27
# Pea                         26
# Clover                      21
# Soybean                     18
# Yellow Pea                  15
# Alfalfa                     12
# SweetCorn                   12
# Mustard                      9
# Wheat                        9
# SeedCorn                     9
# Corn                         6
# Soybean_Potato               3
# SweetCorn_Snapbean           3
# Potato_SweetCorn/Soybean     3
# SweetCorn_Soybean            3
# Heath                        3
# Oats_Clover                  3
# FieldCorn                    3
# Fallow                       3
# Kidney Bean Bean             3
# Snapbean                     2
# Name: Rotation_1year, dtype: int64
# 18 unique values in Rotation_2year
#  ['Soy' 'Potato' 'Wild Rice' 'Kidney Bean' 'Corn' 'Alfalfa' 'soybeans' nan
#  'Snapbean' 'FieldCorn' 'Heath' 'Pea_Corn' 'SweetCorn' 'Oats' 'CornSilage'
#  'Potato_Snapbean' 'Soybean' 'Snapbean_SweetCorn']
#
# Corn                  33
# Potato                32
# Wild Rice             30
# Oats                  21
# Soy                   18
# Kidney Bean           18
# Snapbean              18
# Alfalfa               12
# FieldCorn              9
# SweetCorn              8
# Potato_Snapbean        6
# Heath                  3
# Pea_Corn               3
# soybeans               3
# CornSilage             3
# Soybean                3
# Snapbean_SweetCorn     3
# Name: Rotation_2year, dtype: int64
# 20 unique values in Rotation_3year
#  ['Soy' 'Wild Rice' 'Wheat' 'Corn' 'Potato' 'Alfalfa' 'Kidney Bean' nan
#  'Rye' 'SweetCorn' 'SweetCorn_Potato' 'SeedCorn' 'Soybean' 'Heath'
#  'FieldCorn' 'Snapbean' 'CornSilage' 'Potato_SweetCorn' 'GrainCorn'
#  'Potato_Pea']
#
# Potato              72
# Wild Rice           30
# SweetCorn           24
# Corn                21
# Soy                 15
# SeedCorn             9
# Wheat                6
# Potato_SweetCorn     6
# Snapbean             6
# CornSilage           5
# FieldCorn            3
# GrainCorn            3
# SweetCorn_Potato     3
# Heath                3
# Soybean              3
# Rye                  3
# Kidney Bean          3
# Alfalfa              3
# Potato_Pea           2
# Name: Rotation_3year, dtype: int64
# 13 unique values in Rotation_4year
#  ['Potato' 'Wild Rice' 'Soy' 'Kidney Bean' 'Alfalfa' 'Corn' nan 'Rye'
#  'FieldCorn' 'Soybean' 'Alfafa' 'Clover' 'Pea']
#
# Potato         65
# Wild Rice      18
# Soy            18
# Kidney Bean    18
# Soybean        15
# Corn            9
# FieldCorn       9
# Alfalfa         6
# Rye             6
# Alfafa          3
# Clover          3
# Pea             3
# Name: Rotation_4year, dtype: int64
# 13 unique values in Rotation_5year
#  ['Wild Rice' 'Soy' 'Kidney Bean' 'Corn' 'Alfalfa' nan 'Rye' 'Potato'
#  'SeedCorn' 'Alfafa' 'Otas_Clover' 'CornEarlage' 'SweetCorn']
#
# Wild Rice      27
# Kidney Bean    24
# Corn           21
# SweetCorn      17
# Potato         15
# Soy            12
# SeedCorn        9
# Alfalfa         6
# Rye             6
# Alfafa          3
# Otas_Clover     3
# CornEarlage     3
# Name: Rotation_5year, dtype: int64
# 10 unique values in Rotation_6year
#  ['Wild Rice' 'Potato' nan 'Yellow Pea' 'Corn' 'Woods' 'Rye' 'Soy'
#  'Peas_Snapbean' 'SeedCorn']
#
# Potato           39
# Wild Rice        27
# Corn              9
# Yellow Pea        6
# SeedCorn          6
# Woods             3
# Rye               3
# Soy               3
# Peas_Snapbean     3
# Name: Rotation_6year, dtype: int64
# 8 unique values in Rotation_7year
#  ['Wild Rice' 'Soy' nan 'Potato' 'Woods' 'Kidney Bean' 'Rye' 'Corn']
#
# Wild Rice      36
# Potato         12
# Soy             9
# Kidney Bean     9
# Woods           3
# Rye             3
# Corn            3
# Name: Rotation_7year, dtype: int64
# 3 unique values in Irrigated
#  ['No' 'Yes' nan]
#
# Yes    57
# No     51
# Name: Irrigated, dtype: int64
# 10 unique values in Density
#  [10.   8.5  9.  16.  15.  14.   nan 13.  11.  12. ]
#
# 10.0    21
# 16.0    18
# 11.0    12
# 14.0    10
# 8.5      9
# 9.0      6
# 15.0     3
# 12.0     3
# 13.0     2
# Name: Density, dtype: int64
# 8 unique values in pH_buffer
#  [nan 6.9 6.8 7.  6.7 6.5 6.6 6.4]
#
# 6.9    106
# 6.8     23
# 7.0     17
# 6.7     12
# 6.6      6
# 6.5      3
# 6.4      1
# Name: pH_buffer, dtype: int64

# %%
rf_classifier = RandomForestClassifier(
min_samples_leaf=50,
n_estimators=150,
bootstrap=True,
oob_score=True,
n_jobs=-1,
random_state=42,
max_features='auto')

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_field_information_2'+'.xlsx', engine='xlsxwriter')   
                k=0
                tRF=pd.DataFrame()
                for file in os.listdir(path_field):  
                    if (file[-4:] == '.csv') & (file != '.DS_Store')& (file != 'Icon\r'):              
                        print(file)   
                        D = pd.read_csv(path_field+file)
                        A = D.columns[D.isna().sum()< 40]
                        D2 = D[A]
                        D2.rename(columns={'Column1':'Link_ID'},inplace=True)
                        features_to_encode = D2.columns.drop(['Link_ID','pH_1_1','Variety'])

                        col_trans = make_column_transformer(
                        (OneHotEncoder(),features_to_encode),
                        remainder = "passthrough")


                        data=pd.merge(response,D2,on='Link_ID')
                        #print(data)

                        #data=pd.merge(data,fe_data,on='Link_ID')  
                        data.drop(columns = ['Link_ID','pH_1_1','Variety'],inplace=True)
                        print(data.shape)
                        data.dropna(inplace=True)
                        print(data.shape)
                        AL = []
                        for l in range(0,50):
                            data_train,data_val = train_test_split(data,train_size=0.97, random_state=l)


                            x_column_list = data_train.drop(columns=['y_b']).columns  
                            #Classification RF 

                            pipe = make_pipeline(col_trans, rf_classifier)
                            #pipe.fit(X_train, y_train) 
                            # Fit on data  
                            pipe.fit(data_train[x_column_list],data_train['y_b'])  
                            y_valid = pipe.predict(data_val[x_column_list])

                            report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)  
                            dAll=pd.DataFrame(report_All).transpose() 
                            AL.append(dAll['f1-score'].values)
                        AAA=pd.DataFrame(AL)
                        tRF[k]=AAA.mean()         
                        k=k+1  
                tRF.to_excel(writer, sheet_name=file_folder, index=True)  
        writer.save()
# Out:
# Yield_Plant
# field_information.csv
# (219, 10)
# (200, 10)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
#      43 pipe = make_pipeline(col_trans, rf_classifier)
#      44 #pipe.fit(X_train, y_train)
#      45 # Fit on data
# ---> 46 pipe.fit(data_train[x_column_list],data_train['y_b'])
#      47 y_valid = pipe.predict(data_val[x_column_list])
#      49 report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:600, in Event.wait(self, timeout)
#     598 signaled = self._flag
#     599 if not signaled:
# --> 600     signaled = self._cond.wait(timeout)
#     601 return signaled
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # disease_suppression

# %%
D = pd.read_csv(path_disease+'disease_suppression.csv')

# %%
A = D.columns[D.isna().sum()< 10]

# %%
D2 = D[A]

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_disease_suppression_2'+'.xlsx', engine='xlsxwriter')   
                k=0
                tRF=pd.DataFrame()
                for file in os.listdir(path_disease):  
                    if (file[0] != 'd') & (file[-4:] == '.csv') & (file != '.DS_Store')& (file != 'Icon\r'):              
                        print(file)   
                        data_temp = pd.read_csv(path_disease+file)
                        data_temp.drop(columns={'Unnamed: 0'}, inplace=True)  
                        data=pd.merge(response,data_temp,on='Link_ID')   
                        data.drop(columns = 'Link_ID',inplace=True)
                        print(data.shape)
                        data.dropna(inplace=True)
                        print(data.shape)
                        data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                        output = process_data(data_train,data_val,cv)  
                        tRF[k]=pd.DataFrame(output['f1-score'].values)         
                        k=k+1  
                tRF.to_excel(writer, sheet_name=file_folder, index=True)  
        writer.save()
# Out:
# Yield_Plant
# 6.csv
# (219, 5)
# (218, 5)
# Process LokyProcess-27:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rosa/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rosa/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 483, in _process_worker
#     gc.collect()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
#      22 print(data.shape)
#      23 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 24 output = process_data(data_train,data_val,cv)
#      25 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      26 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Alpha+soil+disease+field

# %%
fe=pd.read_csv(path_field+'field_information.csv')
fe.rename(columns={"Column1":'Link_ID'},inplace=True)
A = fe.columns[fe.isna().sum()< 30]
fe = fe[A]
level_cols = fe.columns 
level_cols =level_cols.drop(['Link_ID','Variety'])
features_to_encode = level_cols.drop(['pH_1_1'])
col_trans = make_column_transformer((OneHotEncoder(),features_to_encode),remainder = "passthrough")

# %%
rf_classifier = RandomForestClassifier(
min_samples_leaf=50,
n_estimators=150,
bootstrap=True,
oob_score=True,
n_jobs=-1,
random_state=42,
max_features='auto')

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_alpha+soil+disease+field'+'.xlsx', engine='xlsxwriter')
                tRF=pd.DataFrame()   
                k=0  

                for level in os.listdir(path_alpha):
                    if (level[-4:] != '.csv') &  (level != '.DS_Store'):
                        for k in range(1,7):
                            f1 = pd.read_csv(path_alpha+level+'/'+str(k)+'.csv')
                            f2 = pd.read_csv(path_soil+str(k)+'.csv')
                            f12 = pd.merge(f1,f2,on='Link_ID')
                            f3 = pd.read_csv(path_disease+str(k)+'.csv')
                            f123=pd.merge(f12,f3,on='Link_ID')
                            f123.drop(columns=['Unnamed: 0_x','Unnamed: 0'],inplace=True)
                            data1 = pd.merge(response,f123,on='Link_ID')
                            fe_data=pd.concat([fe['Link_ID'],fe[level_cols]],axis=1)
                            
                            data = pd.merge(data1,fe_data,on='Link_ID')
                            #print(data)
                            
                            data.drop(columns = 'Link_ID',inplace=True) 
                            data.dropna(inplace=True)
                            print(data.shape)
                            data['Variety2'] = data['Variety2'].replace("RedLittle","Red")
                            
                            
                            AL = []
                            for l in range(0,100):
                                data_train,data_val = train_test_split(data,train_size=0.95, random_state=l)


                                x_column_list = data_train.drop(columns=['y_b']).columns  
                                #Classification RF 

                                pipe = make_pipeline(col_trans, rf_classifier)
                                #pipe.fit(X_train, y_train) 
                                # Fit on data  
                                pipe.fit(data_train[x_column_list],data_train['y_b'])  
                                y_valid = pipe.predict(data_val[x_column_list])

                                report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)  
                                dAll=pd.DataFrame(report_All).transpose() 
                                AL.append(dAll['f1-score'].values)
                            AAA=pd.DataFrame(AL)

                            #output = process_data(data_train,data_val,cv)  
                            tRF[k]=AAA.mean()         
                            k=k+1  
                        tRF.to_excel(writer, sheet_name=level, index=True)  
                writer.save()
# Out:
# Yield_Plant
# (203, 32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
#      43 pipe = make_pipeline(col_trans, rf_classifier)
#      44 #pipe.fit(X_train, y_train)
#      45 # Fit on data
# ---> 46 pipe.fit(data_train[x_column_list],data_train['y_b'])
#      47 y_valid = pipe.predict(data_val[x_column_list])
#      49 report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:600, in Event.wait(self, timeout)
#     598 signaled = self._flag
#     599 if not signaled:
# --> 600     signaled = self._cond.wait(timeout)
#     601 return signaled
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # soil+disease+field

# %%
fe=pd.read_csv(path_field+'field_information.csv')
fe.rename(columns={"Column1":'Link_ID'},inplace=True)
A = fe.columns[fe.isna().sum()< 30]
fe = fe[A]
level_cols = fe.columns 
level_cols =level_cols.drop(['Link_ID','Variety'])
features_to_encode = level_cols.drop(['pH_1_1'])
col_trans = make_column_transformer((OneHotEncoder(),features_to_encode),remainder = "passthrough")

# %%
rf_classifier = RandomForestClassifier(
min_samples_leaf=50,
n_estimators=150,
bootstrap=True,
oob_score=True,
n_jobs=-1,
random_state=42,
max_features='auto')

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_soil+disease+field'+'.xlsx', engine='xlsxwriter')
                tRF=pd.DataFrame()   
                kk=0  


                for k in range(1,7):
                    f2 = pd.read_csv(path_soil+str(k)+'.csv')
                    f3 = pd.read_csv(path_disease+str(k)+'.csv')
                    f23=pd.merge(f2,f3,on='Link_ID')
                    f23.drop(columns=['Unnamed: 0_x','Unnamed: 0_y'],inplace=True)
                    data1 = pd.merge(response,f23,on='Link_ID')
                    fe_data=pd.concat([fe['Link_ID'],fe[level_cols]],axis=1)

                    data = pd.merge(data1,fe_data,on='Link_ID')
                    #print(data)

                    data.drop(columns = 'Link_ID',inplace=True) 
                    data.dropna(inplace=True)
                    print(data.shape)
                    data['Variety2'] = data['Variety2'].replace("RedLittle","Red")


                    AL = []
                    for l in range(0,100):
                        data_train,data_val = train_test_split(data,train_size=0.95, random_state=l)


                        x_column_list = data_train.drop(columns=['y_b']).columns  
                        #Classification RF 

                        pipe = make_pipeline(col_trans, rf_classifier)
                        #pipe.fit(X_train, y_train) 
                        # Fit on data  
                        pipe.fit(data_train[x_column_list],data_train['y_b'])  
                        y_valid = pipe.predict(data_val[x_column_list])

                        report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)  
                        dAll=pd.DataFrame(report_All).transpose() 
                        AL.append(dAll['f1-score'].values)
                    AAA=pd.DataFrame(AL)

                    #output = process_data(data_train,data_val,cv)  
                    tRF[kk]=AAA.mean()         
                    k=kk+1  
                tRF.to_excel(writer, index=True)  
        writer.save()
# Out:
# Yield_Plant
# (209, 22)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
#      40 pipe = make_pipeline(col_trans, rf_classifier)
#      41 #pipe.fit(X_train, y_train)
#      42 # Fit on data
# ---> 43 pipe.fit(data_train[x_column_list],data_train['y_b'])
#      44 y_valid = pipe.predict(data_val[x_column_list])
#      46 report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/pipeline.py:382, in Pipeline.fit(self, X, y, **fit_params)
#     380     if self._final_estimator != "passthrough":
#     381         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 382         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     384 return self
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:512, in BaseForest.fit(self, X, y, sample_weight)
#     501     if y_type in ("multiclass-multioutput", "unknown"):
#     502         # FIXME: we could consider to support multiclass-multioutput if
#     503         # we introduce or reuse a constructor parameter (e.g.
#     504         # oob_score) allowing our user to pass a callable defining the
#     505         # scoring strategy on OOB sample.
#     506         raise ValueError(
#     507             "The type of target cannot be used to compute OOB "
#     508             f"estimates. Got {y_type} while only the following are "
#     509             "supported: continuous, continuous-multioutput, binary, "
#     510             "multiclass, multilabel-indicator."
#     511         )
# --> 512     self._set_oob_score_and_attributes(X, y)
#     514 # Decapsulate classes_ attributes
#     515 if hasattr(self, "classes_") and self.n_outputs_ == 1:
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:749, in ForestClassifier._set_oob_score_and_attributes(self, X, y)
#     739 def _set_oob_score_and_attributes(self, X, y):
#     740     """Compute and set the OOB score and attributes.
#     741
#     742     Parameters
#    (...)
#     747         The target matrix.
#     748     """
# --> 749     self.oob_decision_function_ = super()._compute_oob_predictions(X, y)
#     750     if self.oob_decision_function_.shape[-1] == 1:
#     751         # drop the n_outputs axis if there is a single output
#     752         self.oob_decision_function_ = self.oob_decision_function_.squeeze(axis=-1)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:574, in BaseForest._compute_oob_predictions(self, X, y)
#     569 n_samples_bootstrap = _get_n_samples_bootstrap(
#     570     n_samples,
#     571     self.max_samples,
#     572 )
#     573 for estimator in self.estimators_:
# --> 574     unsampled_indices = _generate_unsampled_indices(
#     575         estimator.random_state,
#     576         n_samples,
#     577         n_samples_bootstrap,
#     578     )
#     580     y_pred = self._get_oob_predictions(estimator, X[unsampled_indices, :])
#     581     oob_pred[unsampled_indices, ...] += y_pred
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:141, in _generate_unsampled_indices(random_state, n_samples, n_samples_bootstrap)
#     138 def _generate_unsampled_indices(random_state, n_samples, n_samples_bootstrap):
#     139     """
#     140     Private function used to forest._set_oob_score function."""
# --> 141     sample_indices = _generate_sample_indices(
#     142         random_state, n_samples, n_samples_bootstrap
#     143     )
#     144     sample_counts = np.bincount(sample_indices, minlength=n_samples)
#     145     unsampled_mask = sample_counts == 0
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:132, in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     128 def _generate_sample_indices(random_state, n_samples, n_samples_bootstrap):
#     129     """
#     130     Private function used to _parallel_build_trees function."""
# --> 132     random_instance = check_random_state(random_state)
#     133     sample_indices = random_instance.randint(0, n_samples, n_samples_bootstrap)
#     135     return sample_indices
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/utils/validation.py:1180, in check_random_state(seed)
#    1178     return np.random.mtrand._rand
#    1179 if isinstance(seed, numbers.Integral):
# -> 1180     return np.random.RandomState(seed)
#    1181 if isinstance(seed, np.random.RandomState):
#    1182     return seed
#
# File mtrand.pyx:184, in numpy.random.mtrand.RandomState.__init__()
#
# File _mt19937.pyx:130, in numpy.random._mt19937.MT19937.__init__()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# # soil+disease

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF+soil+disease'+'.xlsx', engine='xlsxwriter')   
                k=0
                tRF=pd.DataFrame()
                for k in range(1,7):
                    f2 = pd.read_csv(path_soil+str(k)+'.csv')
                    f3 = pd.read_csv(path_disease+str(k)+'.csv')
                    f23=pd.merge(f2,f3,on='Link_ID')
                    f23.drop(columns=['Unnamed: 0_x','Unnamed: 0_y'],inplace=True)
                    data = pd.merge(response,f23,on='Link_ID') 
                    data.drop(columns = 'Link_ID',inplace=True)
                    print(data.shape)
                    data.dropna(inplace=True)
                    print(data.shape)
                    data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                    output = process_data(data_train,data_val,cv)  
                    tRF[k]=pd.DataFrame(output['f1-score'].values)         
                    k=k+1  
                tRF.to_excel(writer, index=True)  
        writer.save()
# Out:
# Yield_Plant
# (219, 17)
# (212, 17)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#      22 print(data.shape)
#      23 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 24 output = process_data(data_train,data_val,cv)
#      25 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      26 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # alpha+soil+disease features

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_alpha+soil+disease'+'.xlsx', engine='xlsxwriter')
                tRF=pd.DataFrame()   
                k=0  




                for level in os.listdir(path_alpha):
                    if (level[-4:] != '.csv') &  (level != '.DS_Store'):
                        for k in range(1,7):
                            f1 = pd.read_csv(path_alpha+level+'/'+str(k)+'.csv')
                            f2 = pd.read_csv(path_soil+str(k)+'.csv')
                            f12 = pd.merge(f1,f2,on='Link_ID')
                            f3 = pd.read_csv(path_disease+str(k)+'.csv')
                            f123=pd.merge(f12,f3,on='Link_ID')
                            f123.drop(columns=['Unnamed: 0_x','Unnamed: 0'],inplace=True)
                            data = pd.merge(response,f123,on='Link_ID')
                            print(data.shape)
                            
                            data.drop(columns = 'Link_ID',inplace=True) 
                            data.dropna(inplace=True)
                            print(data.shape)
                            data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                            output = process_data(data_train,data_val,cv)  
                            tRF[k]=pd.DataFrame(output['f1-score'].values)         
                            k=k+1  
                        tRF.to_excel(writer, sheet_name=level, index=True)  
                writer.save()
# Out:
# Yield_Plant
# (213, 28)
# (206, 27)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
#      31 print(data.shape)
#      32 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 33 output = process_data(data_train,data_val,cv)
#      34 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      35 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # alpha+soil

# %%
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID',response.columns[1]:'y_b'}, inplace=True)     
                writer= pd.ExcelWriter(path_r+'/'+'classification_alpha+soil'+'.xlsx', engine='xlsxwriter')
                tRF=pd.DataFrame()   
                k=0  

                for level in os.listdir(path_alpha):
                    if (level[-4:] != '.csv') &  (level != '.DS_Store'):
                        for k in range(1,7):
                            f1 = pd.read_csv(path_alpha+level+'/'+str(k)+'.csv')
                            f2 = pd.read_csv(path_soil+str(k)+'.csv')
                            f12 = pd.merge(f1,f2,on='Link_ID')
                            #f3 = pd.read_csv(path_disease+str(k)+'.csv')
                            #f123=pd.merge(f12,f3,on='Link_ID')
                            f12.drop(columns=['Unnamed: 0_x'],inplace=True)
                            data = pd.merge(response,f12,on='Link_ID')
                            print(data.shape)
                            
                            data.drop(columns = 'Link_ID',inplace=True) 
                            data.dropna(inplace=True)
                            print(data.shape)
                            data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                            output = process_data(data_train,data_val,cv)  
                            tRF[k]=pd.DataFrame(output['f1-score'].values)         
                            k=k+1  
                        tRF.to_excel(writer, sheet_name=level, index=True)  
                writer.save()
# Out:
# Yield_Plant
# (213, 24)
# (207, 23)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
#      28 print(data.shape)
#      29 data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)
# ---> 30 output = process_data(data_train,data_val,cv)
#      31 tRF[k]=pd.DataFrame(output['f1-score'].values)
#      32 k=k+1
#
# Input In [16], in process_data(data_train, data_val, cv)
#      14 clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#      15 # Fit on data
# ---> 16 clf.fit(data_train[x_column_list],data_train['y_b'])
#      17 best_clf=clf.best_estimator_
#      18 y_valid=best_clf.predict(data_val[x_column_list])
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
