# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.pipeline import Pipeline
import os
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from pandas import ExcelWriter
from sklearn.ensemble import RandomForestClassifier
import openpyxl

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def process_data(data_train,data_val,cv):  
    x_column_list = data_train.drop(columns=['y_b']).columns  
    percent_label=[round(100*len(np.where(data_train['y_b']==0)[0])/len(data_train)),round(100*len(np.where(data_val['y_b']==0)[0])/len(data_val))]  
    #Classification RF  
    pipeRF = Pipeline([('classifier', [RandomForestClassifier()])])  
    param_grid = [  
    {'classifier' : [RandomForestClassifier()], 
    'classifier__n_estimators': [100, 200],
    'classifier__min_samples_split': [8, 10],
    'classifier__min_samples_leaf': [3, 4, 5],
     'classifier__max_depth': [80, 90],
    'classifier__criterion':('gini','entropy'),  
    'classifier__class_weight':('balanced','auto')}]  
    clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')  
    # Fit on data  
    clf.fit(data_train[x_column_list],data_train['y_b'])  
    best_clf=clf.best_estimator_  
    y_valid=best_clf.predict(data_val[x_column_list])  
    report_All = classification_report(data_val['y_b'],y_valid,output_dict=True)  
    dAll=pd.DataFrame(report_All).transpose()  
    return dAll

# %%
cv=RepeatedKFold(n_splits=10,n_repeats=3, random_state=100)

# %%
data_path2 = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/response_type_compare'

# %%
path_list2 = []
#reading files in folder response
for root, dirs, files in os.walk(data_path2, topdown=False):
    for path in dirs:
        path_list2.append(path)
#reading sheet name       
wb = openpyxl.load_workbook(data_path2+'/'+path+'/feature_selection.xlsx')
sheet_list = wb.sheetnames

results_dic = dict.fromkeys(sheet_list)

for sheet_name in results_dic.keys():
    temp_df = pd.DataFrame(columns=path_list2, index=range(0,700))
    for folder in path_list2:
        data_temp = pd.read_excel(data_path2+'/'+folder+'/feature_selection.xlsx', sheet_name=sheet_name)
        temp_df[folder].iloc[
            range(0, len(data_temp['Unnamed: 0'].values))] = data_temp['Unnamed: 0'].values

    results_dic[sheet_name] = temp_df
    
for key in results_dic.keys():
    results_dic[key] = results_dic[key].iloc[range(0,max(30, round(len(data_temp)/3)))]

# %%
data_path = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/response_netcomi_compare'

path_list = []

for root, dirs, files in os.walk(data_path, topdown=False):
    for path in dirs:
        path_list.append(path)

# %%
list_level = ['Class', 'Family', 'Genus', 'Order', 'Phylum']

all_data = dict.fromkeys(dirs)

for folder in path_list:
    
    all_data[folder] = dict.fromkeys(list_level)
    temp_path = data_path+'/'+folder
    temp_file_list = os.listdir(temp_path)
    for file in temp_file_list:
        if 'Count' in file:
            level = file.split('_')[-1][:-4]
            data_temp = pd.read_csv(data_path+'/'+folder+'/'+file,index_col=0)
            data_temp.sort_values(by='dif_close', ascending=False, inplace=True)
            #all_data[folder][level] = data_temp.iloc[range(0,max(40, round(len(data_temp)/3)))]
            all_data[folder][level] = data_temp.iloc[range(0,max(30, round(len(data_temp)/3)))]
            #print(level,":",max(30 ,round(len(data_temp)/3)))

print('Done.')
# Out:
# Done.

# %%
list_level = ['Class', 'Family', 'Genus', 'Order', 'Phylum']
SELECTED_FEATURE = dict.fromkeys(dirs)
for col in range(0,len(list_level)):
    level = list_level[col]
    print(level)
    SELECTED_FEATURE[level] = dict.fromkeys(dirs)
    response_list = path_list
    feature_list = []
    for response in response_list:
        feature_list.append(all_data[response][level].index.union(results_dic[level][response][results_dic[level][response].notnull()].values))
    feature_list = [item for subitem in feature_list for item in subitem]
    feature_list = np.unique(feature_list)
    print(len(feature_list))
    matrix_df = pd.DataFrame(columns = response_list, index = feature_list)
    for response in response_list:
        for feature in feature_list:
                if (feature in all_data[response][level].index) & (feature in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 3
                elif(feature in all_data[response][level].index) &(feature not in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 2##NetComi
                elif (feature not in all_data[response][level].index) &(feature in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 1##ML
                else:
                    matrix_df[response].loc[feature] = 0##NotMLnotNetcomi
            
        #print(matrix_df[response])
#         ree=re[matrix_df[response]==3]
#         print(ree)
#         SELECTED_FEATURE[response][level]= ree.index     
        SELECTED_FEATURE[level][response] = matrix_df[response][matrix_df[response]==3].index
    print(SELECTED_FEATURE[level][response].shape[0])
    matrix_df['Sum'] = 0
    for index in matrix_df.index:
        matrix_df['Sum'].loc[index] = sum(matrix_df.loc[index].values)
    
    matrix_df.sort_values(by='Sum', ascending=False, inplace=True)
    matrix_df=matrix_df.iloc[1:30,:]
# Out:
# Class
# 93
# 7
# Family
# 186
# 8
# Genus
# 306
# 12
# Order
# 168
# 10
# Phylum
# 42
# 21

# %%
SELECTED_FEATURE[level]
# Out:
# {'yield_per_meter': None,
#  'scab_severity': None,
#  'no_tuber_scab': None,
#  'pctg_black_scurf': None,
#  'yield_per_plant': None,
#  'no_tuber_scabpit': None,
#  'no_tuber_hollow': None,
#  'no_tuber': None,
#  'no_tuber_scabsuper': None,
#  'Class': {'yield_per_meter': Index(['Gammaproteobacteria', 'Hydrogenedentia', 'JG30.KF.CM66', 'Kazania',
#          'Ktedonobacteria', 'Latescibacteria', 'S0134.terrestrial.group',
#          'Sumerlaeia'],
#         dtype='object'),
#   'scab_severity': Index(['Gammaproteobacteria', 'Gemmatimonadetes', 'Holophagae', 'KD4.96',
#          'Kryptonia', 'Ktedonobacteria', 'Methylomirabilia', 'Myxococcia',
#          'Phycisphaerae', 'Polyangia', 'Rhodothermia', 'Spirochaetia'],
#         dtype='object'),
#   'no_tuber_scab': Index(['Gitt.GS.136', 'Holophagae', 'Ktedonobacteria', 'Microgenomatia',
#          'Negativicutes', 'Nitrospiria', 'OLB14', 'Parcubacteria',
#          'S0134.terrestrial.group', 'Saccharimonadia', 'Subgroup.22'],
#         dtype='object'),
#   'pctg_black_scurf': Index(['KD4.96', 'Ktedonobacteria', 'Nitrospiria', 'Oligoflexia',
#          'Parcubacteria', 'Planctomycetes', 'S0134.terrestrial.group',
#          'Saccharimonadia', 'Verrucomicrobiae'],
#         dtype='object'),
#   'yield_per_plant': Index(['Gemmatimonadetes', 'Ignavibacteria', 'JG30.KF.CM66', 'Ktedonobacteria',
#          'Myxococcia', 'Nanoarchaeia', 'Nitrospiria', 'Planctomycetes',
#          'Polyangia', 'Sericytochromatia'],
#         dtype='object'),
#   'no_tuber_scabpit': Index(['Gemmatimonadetes', 'Gitt.GS.136', 'Holophagae', 'JG30.KF.CM66',
#          'Ktedonobacteria', 'OLB14', 'Oligoflexia', 'Planctomycetes',
#          'Polyangia', 'Saccharimonadia'],
#         dtype='object'),
#   'no_tuber_hollow': Index(['KD4.96', 'Kryptonia', 'Ktedonobacteria', 'Methylomirabilia',
#          'Myxococcia', 'Oligoflexia', 'Parcubacteria', 'Planctomycetes',
#          'Polyangia', 'Saccharimonadia'],
#         dtype='object'),
#   'no_tuber': Index(['Fimbriimonadia', 'Gammaproteobacteria', 'Gitt.GS.136', 'Holophagae',
#          'KD4.96', 'Ktedonobacteria', 'Myxococcia', 'Oligoflexia', 'Polyangia',
#          'Saccharimonadia'],
#         dtype='object'),
#   'no_tuber_scabsuper': Index(['Gammaproteobacteria', 'Ktedonobacteria', 'Myxococcia', 'Phycisphaerae',
#          'Polyangia', 'S0134.terrestrial.group', 'Subgroup.22'],
#         dtype='object')},
#  'Family': {'yield_per_meter': Index(['Geodermatophilaceae', 'JG30.KF.CM45', 'Kineosporiaceae',
#          'Lachnospiraceae', 'Leptolyngbyaceae', 'Rhodanobacteraceae',
#          'Rhodomicrobiaceae', 'Rubritaleaceae', 'Spirosomaceae',
#          'Streptomycetaceae', 'Sumerlaeaceae'],
#         dtype='object'),
#   'scab_severity': Index(['Hyphomicrobiaceae', 'Ilumatobacteraceae', 'Methyloligellaceae',
#          'Mitochondria', 'Nitrosomonadaceae', 'Reyranellaceae',
#          'Rhizobiales.Incertae.Sedis', 'Rhodothermaceae', 'Roseiflexaceae',
#          'Solibacteraceae'],
#         dtype='object'),
#   'no_tuber_scab': Index(['Koribacteraceae', 'LWQ8', 'Lachnospiraceae', 'Microbacteriaceae',
#          'Micrococcaceae', 'Nitrospiraceae', 'Planococcaceae', 'Rhizobiaceae',
#          'Rhizobiales.Incertae.Sedis', 'Rubritaleaceae', 'SC.I.84',
#          'Solibacteraceae', 'Streptomycetaceae'],
#         dtype='object'),
#   'pctg_black_scurf': Index(['Hydrogenophilaceae', 'Ilumatobacteraceae', 'JG30.KF.CM45',
#          'Myxococcaceae', 'Planococcaceae', 'Pseudomonadaceae',
#          'Pyrinomonadaceae', 'Rhizobiales.Incertae.Sedis', 'Roseiflexaceae',
#          'Solirubrobacteraceae', 'Sphingomonadaceae', 'Streptomycetaceae',
#          'Sutterellaceae'],
#         dtype='object'),
#   'yield_per_plant': Index(['Gemmataceae', 'Holosporaceae', 'Ilumatobacteraceae', 'KF.JG30.B3',
#          'Kineosporiaceae', 'Koribacteraceae', 'Labraceae', 'Planococcaceae',
#          'Pseudomonadaceae', 'Rhizobiales.Incertae.Sedis', 'Saccharimonadaceae',
#          'Solirubrobacteraceae', 'Sporichthyaceae', 'Streptomycetaceae'],
#         dtype='object'),
#   'no_tuber_scabpit': Index(['Gemmatimonadaceae', 'Kineosporiaceae', 'Ktedonobacteraceae', 'LWQ8',
#          'Micrococcaceae', 'Solibacteraceae', 'Sporichthyaceae'],
#         dtype='object'),
#   'no_tuber_hollow': Index(['Geodermatophilaceae', 'Hyphomicrobiaceae', 'Ilumatobacteraceae',
#          'Intrasporangiaceae', 'Methyloligellaceae', 'Mycobacteriaceae',
#          'Oxalobacteraceae', 'Rhizobiales.Incertae.Sedis', 'Roseiflexaceae',
#          'SB.5', 'SC.I.84', 'Solibacteraceae', 'Sphingomonadaceae'],
#         dtype='object'),
#   'no_tuber': Index(['Gemmatimonadaceae', 'Holophagaceae', 'Methyloligellaceae',
#          'Microbacteriaceae', 'Myxococcaceae', 'Pseudonocardiaceae',
#          'Roseiflexaceae', 'Solirubrobacteraceae', 'Sphingobacteriaceae',
#          'Sphingomonadaceae'],
#         dtype='object'),
#   'no_tuber_scabsuper': Index(['Gemmatimonadaceae', 'Ilumatobacteraceae', 'Ktedonobacteraceae', 'LWQ8',
#          'Methylococcaceae', 'Phycisphaeraceae', 'Planococcaceae',
#          'Pseudonocardiaceae'],
#         dtype='object')},
#  'Genus': {'yield_per_meter': Index(['Flavobacterium', 'Microlunatus', 'Pseudonocardia', 'Quadrisphaera',
#          'Rhizobacter', 'Rhodomicrobium', 'Subgroup.10'],
#         dtype='object'),
#   'scab_severity': Index(['Gaiella', 'Iamia', 'Ilumatobacter', 'Jatrophihabitans',
#          'Mesorhizobium', 'Microvirga', 'Nannocystis', 'Paenibacillus', 'Puia',
#          'Quadrisphaera', 'RB41'],
#         dtype='object'),
#   'no_tuber_scab': Index(['Luteimonas', 'Luteolibacter', 'Marmoricola', 'Microbacterium',
#          'Microvirga', 'Pedobacter', 'Pseudolabrys', 'RB41', 'Rhodoplanes',
#          'Roseiarcus', 'Solirubrobacter', 'Subgroup.10'],
#         dtype='object'),
#   'pctg_black_scurf': Index(['Flavobacterium', 'Iamia', 'Mesorhizobium', 'Niastella',
#          'Planotetraspora', 'Plot4.2H12', 'RB41', 'Sphingomonas', 'Sporosarcina',
#          'Subgroup.10', 'possible.genus.04'],
#         dtype='object'),
#   'yield_per_plant': Index(['Haliangium', 'Knoellia', 'Luteolibacter', 'Nocardioides',
#          'Pseudarthrobacter', 'Pseudomonas', 'Rhodomicrobium',
#          'Rhodopseudomonas', 'Solirubrobacter', 'Sphingomonas', 'Sporosarcina'],
#         dtype='object'),
#   'no_tuber_scabpit': Index(['Kineosporia', 'Microvirga', 'Ohtaekwangia', 'Pedomicrobium',
#          'Phaselicystis', 'Pseudoxanthomonas', 'Rhodoplanes', 'Solirubrobacter',
#          'Sorangium', 'Steroidobacter'],
#         dtype='object'),
#   'no_tuber_hollow': Index(['Flavisolibacter', 'Haliangium', 'Mesorhizobium',
#          'Pedococcus.Phycicoccus', 'Pedomicrobium', 'Pseudolabrys',
#          'Pseudonocardia', 'Rhizobacter', 'Rummeliibacillus'],
#         dtype='object'),
#   'no_tuber': Index(['Flavobacterium', 'Holophaga', 'Microbacterium', 'Microlunatus',
#          'Microvirga', 'Oryzihumus', 'Pedococcus.Phycicoccus', 'Pseudolabrys',
#          'Pseudomonas', 'Solirubrobacter', 'Streptomyces'],
#         dtype='object'),
#   'no_tuber_scabsuper': Index(['Fictibacillus', 'Iamia', 'Jatrophihabitans', 'KD3.10', 'Massilia',
#          'Microlunatus', 'Pedococcus.Phycicoccus', 'Pedomicrobium',
#          'Rhodoplanes', 'Roseiarcus', 'SM1A02', 'Sporosarcina'],
#         dtype='object')},
#  'Order': {'yield_per_meter': Index(['Elsterales', 'Erysipelotrichales', 'Flavobacteriales', 'Frankiales',
#          'Kineosporiales', 'Ktedonobacterales', 'Leptolyngbyales',
#          'Myxococcales', 'Oxyphotobacteria.Incertae.Sedis',
#          'Propionibacteriales', 'Pseudonocardiales'],
#         dtype='object'),
#   'scab_severity': Index(['Frankiales', 'Gammaproteobacteria.Incertae.Sedis', 'Ktedonobacterales',
#          'PAUC26f', 'PLTA13', 'Paenibacillales', 'Pyrinomonadales',
#          'Reyranellales', 'Rhizobiales', 'Rickettsiales', 'Rokubacteriales',
#          'SBR1031', 'Solibacterales', 'Sphingomonadales'],
#         dtype='object'),
#   'no_tuber_scab': Index(['Elsterales', 'Erysipelotrichales',
#          'Gammaproteobacteria.Incertae.Sedis', 'Gemmatales', 'Isosphaerales',
#          'Nitrospirales', 'Pedosphaerales', 'Solibacterales',
#          'Sphingobacteriales'],
#         dtype='object'),
#   'pctg_black_scurf': Index(['Gammaproteobacteria.Incertae.Sedis', 'Isosphaerales',
#          'Micromonosporales', 'PB19', 'Paenibacillales',
#          'Peptostreptococcales.Tissierellales', 'Pyrinomonadales',
#          'Solirubrobacterales', 'Sphingomonadales', 'Streptomycetales',
#          'Streptosporangiales'],
#         dtype='object'),
#   'yield_per_plant': Index(['Dongiales', 'Elsterales', 'Fibrobacterales', 'Ktedonobacterales',
#          'Leptolyngbyales', 'Microtrichales', 'PAUC26f', 'PB19',
#          'Paenibacillales', 'Streptomycetales', 'Streptosporangiales',
#          'Subgroup.7'],
#         dtype='object'),
#   'no_tuber_scabpit': Index(['Elsterales', 'Kineosporiales', 'Pedosphaerales', 'Rhizobiales',
#          'Rickettsiales', 'SBR1031', 'Sphingomonadales', 'Subgroup.7'],
#         dtype='object'),
#   'no_tuber_hollow': Index(['Elsterales', 'Fibrobacterales', 'Frankiales', 'Haliangiales',
#          'IMCC26256', 'Leptolyngbyales', 'Paenibacillales', 'Pedosphaerales',
#          'Polyangiales', 'Reyranellales', 'Sphingomonadales'],
#         dtype='object'),
#   'no_tuber': Index(['Haliangiales', 'Kryptoniales', 'PAUC26f', 'Paenibacillales',
#          'Pseudonocardiales', 'Rokubacteriales', 'SBR1031', 'Solibacterales',
#          'Sphingomonadales', 'Streptomycetales'],
#         dtype='object'),
#   'no_tuber_scabsuper': Index(['Isosphaerales', 'Micropepsales', 'Paenibacillales', 'Pedosphaerales',
#          'Pseudonocardiales', 'Pyrinomonadales', 'RBG.13.54.9', 'Rhizobiales',
#          'Rickettsiales', 'Solibacterales'],
#         dtype='object')},
#  'Phylum': {'yield_per_meter': Index(['Acidobacteriota', 'Actinobacteriota', 'Bacteroidota', 'Chloroflexi',
#          'Cyanobacteria', 'Dependentiae', 'Elusimicrobiota', 'Entotheonellaeota',
#          'Fibrobacterota', 'Firmicutes', 'Gemmatimonadota', 'Halobacterota',
#          'Hydrogenedentes', 'Latescibacterota', 'Patescibacteria', 'RCP2.54',
#          'Spirochaetota', 'Sumerlaeota', 'WPS.2', 'WS2', 'Zixibacteria'],
#         dtype='object'),
#   'scab_severity': Index(['Acidobacteriota', 'Actinobacteriota', 'Bacteroidota', 'Chloroflexi',
#          'Cyanobacteria', 'Desulfobacterota', 'Fibrobacterota', 'Firmicutes',
#          'Gemmatimonadota', 'Latescibacterota', 'MBNT15', 'NB1.j',
#          'Patescibacteria', 'Planctomycetota', 'RCP2.54',
#          'SAR324.clade.Marine.group.B.', 'Spirochaetota', 'Sva0485'],
#         dtype='object'),
#   'no_tuber_scab': Index(['Acidobacteriota', 'Actinobacteriota', 'Bacteroidota',
#          'Bdellovibrionota', 'Chloroflexi', 'Cyanobacteria', 'Elusimicrobiota',
#          'Entotheonellaeota', 'Firmicutes', 'Gemmatimonadota', 'Halobacterota',
#          'NB1.j', 'Patescibacteria', 'Planctomycetota', 'Proteobacteria',
#          'RCP2.54', 'SAR324.clade.Marine.group.B.', 'Spirochaetota',
#          'Sumerlaeota', 'Verrucomicrobiota', 'WPS.2'],
#         dtype='object'),
#   'pctg_black_scurf': Index(['Acidobacteriota', 'Armatimonadota', 'Bacteroidota', 'Chloroflexi',
#          'Cyanobacteria', 'Deinococcota', 'Desulfobacterota', 'Halobacterota',
#          'Hydrogenedentes', 'MBNT15', 'Methylomirabilota', 'Myxococcota',
#          'NB1.j', 'Patescibacteria', 'Planctomycetota', 'Proteobacteria',
#          'RCP2.54', 'Spirochaetota', 'Verrucomicrobiota'],
#         dtype='object'),
#   'yield_per_plant': Index(['Abditibacteriota', 'Acidobacteriota', 'Actinobacteriota',
#          'Bacteroidota', 'Bdellovibrionota', 'Chloroflexi', 'Cyanobacteria',
#          'Elusimicrobiota', 'Fibrobacterota', 'Firmicutes', 'Gemmatimonadota',
#          'Nanoarchaeota', 'Nitrospirota', 'Patescibacteria', 'Planctomycetota',
#          'Proteobacteria', 'RCP2.54', 'Spirochaetota', 'Verrucomicrobiota',
#          'WS2'],
#         dtype='object'),
#   'no_tuber_scabpit': Index(['Acidobacteriota', 'Actinobacteriota', 'Bacteroidota',
#          'Bdellovibrionota', 'Cyanobacteria', 'Desulfobacterota',
#          'Elusimicrobiota', 'Firmicutes', 'Gemmatimonadota', 'NB1.j',
#          'Nitrospirota', 'Patescibacteria', 'Planctomycetota', 'Proteobacteria',
#          'RCP2.54', 'Spirochaetota', 'Thermoplasmatota', 'Verrucomicrobiota',
#          'WPS.2', 'WS2'],
#         dtype='object'),
#   'no_tuber_hollow': Index(['Acidobacteriota', 'Actinobacteriota', 'Bacteroidota',
#          'Bdellovibrionota', 'Chloroflexi', 'Cyanobacteria', 'Deinococcota',
#          'Desulfobacterota', 'Firmicutes', 'Gemmatimonadota', 'Latescibacterota',
#          'Methylomirabilota', 'NB1.j', 'Nanoarchaeota', 'Nitrospinota',
#          'Patescibacteria', 'Planctomycetota', 'RCP2.54',
#          'SAR324.clade.Marine.group.B.', 'Spirochaetota', 'WS2'],
#         dtype='object'),
#   'no_tuber': Index(['Abditibacteriota', 'Acidobacteriota', 'Actinobacteriota',
#          'Bacteroidota', 'Chloroflexi', 'Cyanobacteria', 'Desulfobacterota',
#          'Elusimicrobiota', 'Entotheonellaeota', 'Firmicutes', 'Gemmatimonadota',
#          'NB1.j', 'Nitrospinota', 'Patescibacteria', 'Planctomycetota',
#          'Proteobacteria', 'RCP2.54', 'SAR324.clade.Marine.group.B.',
#          'Verrucomicrobiota', 'WPS.2', 'Zixibacteria'],
#         dtype='object'),
#   'no_tuber_scabsuper': Index(['Acidobacteriota', 'Actinobacteriota', 'Armatimonadota', 'Bacteroidota',
#          'Bdellovibrionota', 'Chloroflexi', 'Crenarchaeota', 'Cyanobacteria',
#          'Entotheonellaeota', 'Fibrobacterota', 'Firmicutes', 'Gemmatimonadota',
#          'Halobacterota', 'NB1.j', 'Nanoarchaeota', 'Nitrospirota',
#          'Patescibacteria', 'Planctomycetota', 'Proteobacteria', 'RCP2.54',
#          'WPS.2'],
#         dtype='object')}}

# %%
import json

# %%
with open('convert.txt', 'w') as convert_file: 

     convert_file.write(json.dumps(SELECTED_FEATURE[level]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#       1 with open('convert.txt', 'w') as convert_file:
# ----> 3      convert_file.write(json.dumps(SELECTED_FEATURE[level]))
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File ~/opt/anaconda3/envs/soil_env2/lib/python3.10/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type Index is not JSON serializable

# %%
path_response='/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/response_sklearn/'  
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID','x1':'y_b'}, inplace=True)  
                response.drop(columns=response.columns[2], inplace=True)  
                response=response.drop(columns='Variety2')  
                path_x = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/normalized_data_sklearn/'  
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_FS'+'.xlsx', engine='xlsxwriter')   
                for file_folder in os.listdir(path_x):  
                    if (file_folder[-4:] != '.csv') & (file_folder != '.DS_Store')& (file_folder != 'Icon\r'):          
                        path = path_x+file_folder  
                        os.chdir(path)  
                        file_list = []  
                        tRF=pd.DataFrame()  
                        tcluster=pd.DataFrame()  
                        k=0  
                        for file in os.listdir(path):  
                            if (file[0] != 't') & (file[-4:] == '.csv') & (file != '.DS_Store')& (file_folder != 'Icon\r'):  
                                print(file)  
                                file_list.append(file)  
                                data_temp = pd.read_csv(file) 
                                data_temp.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True) 
                                A = [item for item in SELECTED_FEATURE[file_folder][file_response]]
                                A.insert(0, "Link_ID")
                                data_temp = data_temp[A]
                                data_temp.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)  
                                data=pd.merge(response,data_temp,on='Link_ID')
                                
                                data.drop(columns = 'Link_ID',inplace=True)  
                                data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                                output = process_data(data_train,data_val,cv)  
                                tRF[k]=pd.DataFrame(output['f1-score'].values)         
                                k=k+1  
                        tRF.to_excel(writer, sheet_name=file_folder, index=True)  
                writer.save()
# Out:
# yield_per_meter
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# scab_severity
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scab
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# pctg_black_scurf
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# yield_per_plant
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scabpit
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_hollow
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scabsuper
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv

# %%
list_level = ['Class', 'Family', 'Genus', 'Order', 'Phylum']
SELECTED_FEATURE = dict.fromkeys(dirs)
SELECTED_FEATURE_0 = dict.fromkeys(dirs)
for col in range(0,len(list_level)):
    level = list_level[col]
    print(level)
    SELECTED_FEATURE[level] = dict.fromkeys(dirs)
    SELECTED_FEATURE_0[level] = dict.fromkeys(dirs)
    response_list = path_list
    feature_list = []
    for response in response_list:
        feature_list.append(all_data[response][level].index.union(results_dic[level][response][results_dic[level][response].notnull()].values))
    feature_list = [item for subitem in feature_list for item in subitem]
    feature_list = np.unique(feature_list)
    print(len(feature_list))
    matrix_df = pd.DataFrame(columns = response_list, index = feature_list)
    for response in response_list:
        for feature in feature_list:
                if (feature in all_data[response][level].index) & (feature in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 3
                elif(feature in all_data[response][level].index) &(feature not in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 2##NetComi
                elif (feature not in all_data[response][level].index) &(feature in results_dic[level][response].values):
                    matrix_df[response].loc[feature] = 1##ML
                else:
                    matrix_df[response].loc[feature] = 0##NotMLnotNetcomi
            
        #print(matrix_df[response])
#         ree=re[matrix_df[response]==3]
#         print(ree)
#         SELECTED_FEATURE[response][level]= ree.index     
        SELECTED_FEATURE[level][response] = matrix_df[response][matrix_df[response]==3].index
        print(SELECTED_FEATURE[level][response].shape[0])
        SELECTED_FEATURE_0[level][response] = matrix_df[response][matrix_df[response]==0].index[0:SELECTED_FEATURE[level][response].shape[0]]
        #print(SELECTED_FEATURE_0[level][response].shape[0])
    
    matrix_df['Sum'] = 0
    for index in matrix_df.index:
        matrix_df['Sum'].loc[index] = sum(matrix_df.loc[index].values)
    
    matrix_df.sort_values(by='Sum', ascending=False, inplace=True)
    matrix_df=matrix_df.iloc[1:30,:]
# Out:
# Class
# 93
# 8
# 12
# 11
# 9
# 10
# 10
# 10
# 10
# 7
# Family
# 186
# 11
# 10
# 13
# 13
# 14
# 7
# 13
# 10
# 8
# Genus
# 306
# 7
# 11
# 12
# 11
# 11
# 10
# 9
# 11
# 12
# Order
# 168
# 11
# 14
# 9
# 11
# 12
# 8
# 11
# 10
# 10
# Phylum
# 42
# 21
# 18
# 21
# 19
# 20
# 20
# 21
# 21
# 21

# %%
path_response='/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/response_sklearn/'  
for file_response in os.listdir(path_response):  
    if (file_response != '.DS_Store') & (file_response != 'Icon\r'):  
        print(file_response)  
        path_r= path_response+file_response  
        os.chdir(path_r)  
        for re in os.listdir(path_r):  
            if re[0:8] == 'response':  
                response = pd.read_csv(path_response+file_response+'/'+re)  
                response.rename(columns={'Column1':'Link_ID','x1':'y_b'}, inplace=True)  
                response.drop(columns=response.columns[2], inplace=True)  
                response=response.drop(columns='Variety2')  
                path_x = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Code/python code local/Main Data Files/normalized_data_sklearn/'  
                writer= pd.ExcelWriter(path_r+'/'+'classification_RF_FS_notImportant'+'.xlsx', engine='xlsxwriter')   
                for file_folder in os.listdir(path_x):  
                    if (file_folder[-4:] != '.csv') & (file_folder != '.DS_Store')& (file_folder != 'Icon\r'):          
                        path = path_x+file_folder  
                        os.chdir(path)  
                        file_list = []  
                        tRF=pd.DataFrame()  
                        tcluster=pd.DataFrame()  
                        k=0  
                        for file in os.listdir(path):  
                            if (file[0] != 't') & (file[-4:] == '.csv') & (file != '.DS_Store')& (file_folder != 'Icon\r'):  
                                print(file)  
                                file_list.append(file)  
                                data_temp = pd.read_csv(file) 
                                data_temp.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True) 
                                A = [item for item in SELECTED_FEATURE_0[file_folder][file_response]]
                                A.insert(0, "Link_ID")
                                data_temp = data_temp[A]
                                data_temp.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)  
                                data=pd.merge(response,data_temp,on='Link_ID')
                                
                                data.drop(columns = 'Link_ID',inplace=True)  
                                data_train,data_val = train_test_split(data,train_size=0.8, random_state=42)  
                                output = process_data(data_train,data_val,cv)  
                                tRF[k]=pd.DataFrame(output['f1-score'].values)         
                                k=k+1  
                        tRF.to_excel(writer, sheet_name=file_folder, index=True)  
                writer.save()
# Out:
# yield_per_meter
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# scab_severity
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scab
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# pctg_black_scurf
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# yield_per_plant
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scabpit
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_hollow
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
# no_tuber_scabsuper
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
#  1 _ 3 .csv
#  4 _ 1 .csv
#  5 _ 1 .csv
#  1 _ 2 .csv
#  1 _ 4 .csv
#  3 _ 1 .csv
#  2 _ 1 .csv
#  2 _ 2 .csv
#  3 _ 2 .csv
#  4 _ 4 .csv
#  5 _ 4 .csv
#  2 _ 3 .csv
#  3 _ 3 .csv
#  1 _ 1 .csv
#  3 _ 4 .csv
#  2 _ 4 .csv
#  5 _ 3 .csv
#  4 _ 3 .csv
#  5 _ 2 .csv
#  4 _ 2 .csv
