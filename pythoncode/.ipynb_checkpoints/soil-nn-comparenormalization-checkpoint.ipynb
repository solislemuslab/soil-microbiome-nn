# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use(['bmh'])
from sklearn.model_selection import RepeatedKFold

from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import roc_auc_score
from sklearn.metrics import brier_score_loss
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import roc_curve, roc_auc_score, make_scorer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDClassifier, LogisticRegressionCV,LogisticRegression
from sklearn.feature_selection import RFE, RFECV
from sklearn.linear_model import RidgeClassifierCV, LassoCV, LassoLarsCV, LassoLarsIC, Ridge, Lasso
from sklearn import svm, datasets
from scipy.stats import boxcox
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from itertools import product
from sklearn.linear_model import LassoLarsCV
from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error,r2_score
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.linear_model import ElasticNet
import os
from pandas import ExcelWriter
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, adjusted_rand_score
from kneed import KneeLocator

# %%
# %%javascript
# (function(on) {
# const e=$( "<a>Setup failed</a>" );
# const ns="js_jupyter_suppress_warnings";
# var cssrules=$("#"+ns);
# if(!cssrules.length) cssrules = $("<style id='"+ns+"' type='text/css'>div.output_stderr { } </style>").appendTo("head");
# e.click(function() {
#     var s='Showing';
#     cssrules.empty()
#     if(on) {
#         s='Hiding';
#         cssrules.append("div.output_stderr, div[data-mime-type*='.stderr'] { display:none; }");
#     }
#     e.text(s+' warnings (click to toggle)');
#     on=!on;
# }).click();
# $(element).append(e);
# })(true);

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix',cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]*100
    thresh = cm.max()/2.0
    for i,j in product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,i,cm[i,j], horizontalalignment='center',color='white' if cm[i,j] > thresh else 'black')
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predict label')
    plt.show()

# %%
def stepwise_selection(data, target,SL_in=0.05,SL_out = 0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<SL_in):
            best_features.append(new_pval.idxmin())
            while(len(best_features)>0):
                best_features_with_constant = sm.add_constant(data[best_features])
                p_values = sm.OLS(target, best_features_with_constant).fit().pvalues[1:]
                max_p_value = p_values.max()
                if(max_p_value >= SL_out):
                    excluded_feature = p_values.idxmax()
                    best_features.remove(excluded_feature)
                else:
                    break 
        else:
            break
    return best_features

# %%
def process_data(data_original,data,n_train,cv,q,NumofR):
    if 'Unnamed: 0' in data.columns:
        data.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)
    data['y_binary']=data_original['y_binary'].values
    data['Yield_per_plant']=data_original['Yield_per_plant'].values
    fitted_y, fitted_lambda = stats.boxcox(data['Yield_per_plant'])
    data['y_boxcox'] = fitted_y  
    x_column_list = data.drop(columns=['Link_ID', 'y_binary', 'Yield_per_plant','y_boxcox']).columns
    ###Split Data  
    data_train = data.iloc[0:n_train]
    data_val = data.iloc[n_train:]
    y_b = 'y_binary'
    y_c = 'Yield_per_plant'
    y_c_boxcox = 'y_boxcox'
    percent_label=[round(100*len(np.where(data_train[y_b]==0)[0])/len(data_train)),round(100*len(np.where(data_val[y_b]==0)[0])/len(data_val))]
    #Feature Selection
    feature_list1 = data[x_column_list].max().sort_values(ascending=False)[data[x_column_list].max()>np.quantile(data[x_column_list].max(),q)].index
    #apply SelectKBest class to extract top 20 best features
    bestfeatures = SelectKBest(score_func=mutual_info_regression, k=20)
    fit = bestfeatures.fit(data[x_column_list],data[y_c])
    dfscores = pd.DataFrame(fit.scores_)
    dfcolumns = pd.DataFrame(x_column_list)
    #concat two dataframes for better visualization 
    featureScores = pd.concat([dfcolumns,dfscores],axis=1)
    featureScores.columns = ['Variable','Score']  #naming the dataframe columns
    feature_list2 = featureScores.nlargest(20,'Score')
    feature_list3=stepwise_selection(data.drop(columns=
                                ['Link_ID', 'y_binary', 'Yield_per_plant', 'y_boxcox']),data[y_c])
    reg = LassoCV(cv=cv).fit(data_train[x_column_list], data_train[y_c])
    lassoCoefs0 = pd.DataFrame(
    data=reg.coef_[np.where(reg.coef_ != 0)[0]], 
    index=data[x_column_list].columns[np.where(reg.coef_ != 0)[0]],columns=['LASSO Coefs1'])
    feature_list4=lassoCoefs0
    
    parameters = {'n_estimators':(10,20,100, 500),
                  'min_samples_split':(2,3,4),
                  'min_samples_leaf':(1,2,3)}

    gb_model = GradientBoostingRegressor(random_state=7, warm_start=False)
    grid_obj = GridSearchCV(gb_model, param_grid=parameters, verbose=1, n_jobs=4, cv=cv)
    grid_obj = grid_obj.fit(data_train[x_column_list],data_train[y_c])
    gb_model_best = grid_obj.best_estimator_
    y_hat = gb_model_best.predict(data_val[x_column_list])
    FeatImportance = gb_model_best.feature_importances_
    GBCoefs = pd.DataFrame(index=data_train[x_column_list].columns, data=FeatImportance,columns=['Coefs'])
    imp_coef = GBCoefs.sort_values(by='Coefs')
    feature_list6=imp_coef.loc[imp_coef['Coefs']>np.quantile(imp_coef,0.7)]
    feature_list6 = [item for item in feature_list6.index]
    
    
    
    parameters = {'n_estimators':(10,20,100, 500),
              'min_samples_split':(2,3,4),
              'min_samples_leaf':(1,2,3)}
    rf_model = RandomForestRegressor(warm_start=False)
    grid_obj = GridSearchCV(rf_model, param_grid=parameters, verbose=1, n_jobs=4, cv=cv)
    grid_obj = grid_obj.fit(data_train[x_column_list],data_train[y_c])
    rf_model_best = grid_obj.best_estimator_
    y_hat_rf = rf_model_best.predict(data_val[x_column_list])  
    rf_model_best.score(data_val[x_column_list],data_val[y_c])
    FeatImportance = rf_model_best.feature_importances_
    RFCoefs = pd.DataFrame(index=data_train[x_column_list].columns, data=FeatImportance,columns=['Coefs'])
    imp_coef_RF = RFCoefs.sort_values(by='Coefs')
    feature_list7=imp_coef_RF.loc[imp_coef_RF['Coefs']>np.quantile(imp_coef_RF,0.7)]
    feature_list7 = [item for item in feature_list7.index]
    
    mi = mutual_info_regression(data_train[x_column_list],data_train[y_c], discrete_features=False, n_neighbors=3, copy=True, random_state=None)
    MI=pd.DataFrame(mi)
    MI['OTU']=data[x_column_list].columns
    MI=MI.set_index('OTU')
    MI=MI.sort_values(0,ascending=False)
    feature_list8=MI[MI[0]>np.quantile(mi,q)].index
    
    methodList = ['Maximum', 
              'KBest', 
              'Stepwise Regression', 
              'Lasso CV', 
              'GBM', 
              'Random Forest', 
              'Mutual Info']
    featureList = [[item for item in feature_list1], 
               [item for item in feature_list2['Variable'].values], 
               feature_list3, 
               [item for item in feature_list4.index], 
               feature_list6, 
               feature_list7,
               [item for item in feature_list8]]
    featureUniqueList = np.unique([item for sublist in featureList for item in sublist])
    featureDictionary = dict.fromkeys(featureUniqueList)
    for key in featureDictionary.keys():
        featureDictionary[key] = []
    

    for feature in featureUniqueList:
    
        for i, method in enumerate(methodList):
        
            if feature in featureList[i]:
                featureDictionary[feature].append(method)   

    featureDf = pd.DataFrame(index=featureUniqueList, columns=methodList)
    featureDf['Count'] = 0

    for feature in featureDictionary.keys(): 
        for method in methodList:
        
            if method in featureDictionary[feature]:
            
                featureDf['Count'][feature] += 1
            
                featureDf[method][feature] = 'X'
            else:
                featureDf[method][feature] = '-' 
    featureDf.sort_values(by='Count', ascending=False, inplace=True)

    #Classification RF
    pipeRF = Pipeline([('classifier', [RandomForestClassifier()])])
    param_grid = [
    {'classifier' : [RandomForestClassifier()],
    'classifier__criterion':('gini','entropy'),
    'classifier__class_weight':('balanced','auto')}]
    clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')

    # Fit on data
    clf.fit(data_train[x_column_list],data_train[y_b])
    best_clf=clf.best_estimator_
    y_valid=best_clf.predict(data_val[x_column_list])
    matrix = confusion_matrix(data_val[y_b], y_valid)
    report_RF = classification_report(data_val[y_b],y_valid,output_dict=True)
    dRF = pd.DataFrame(report_RF).transpose()
    #Classification All Model
    pipe = Pipeline([('classifier', [RandomForestClassifier(),DecisionTreeClassifier(),SGDClassifier(),SVC(),KNeighborsClassifier()])])
    param_grid = [
    {'classifier' : [RandomForestClassifier()]},   
    {'classifier' : [DecisionTreeClassifier()]}, 
    {'classifier' : [SGDClassifier()]},
    {'classifier' : [SVC()],      
    'classifier__class_weight':('balanced','auto'),
    'classifier__gamma' : [1,0.1,0.01,0.001]},
    #'classifier__ kernel': ['rbf', 'poly', 'sigmoid']},
    {'classifier' : [KNeighborsClassifier()],
     'classifier__n_neighbors':list(range(5,25))} ]
    clf = GridSearchCV(pipe, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
    # Fit on data
    clf.fit(data_train[x_column_list],data_train[y_b])
    best_clf=clf.best_estimator_
    y_valid=best_clf.predict(data_val[x_column_list])
    report_All = classification_report(data_val[y_b],y_valid,output_dict=True)
    dAll=pd.DataFrame(report_All).transpose()
    #Classification by selected feature
    selected_features = featureDf[featureDf['Count']>2].index
    
    clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
    # Fit on data
    clf.fit(data_train[selected_features],data_train[y_b])
    best_clf=clf.best_estimator_
    y_valid=best_clf.predict(data_val[selected_features])
    report_selected = classification_report(data_val[y_b],y_valid,output_dict=True)
    dfselected1=pd.DataFrame(report_selected).transpose()



    ### from original data and selected features
    new_column_list = [col.replace('.','-') for col in selected_features]
    clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
    # Fit on data
    clf.fit(data_original[new_column_list].div(data_original[new_column_list].sum(axis=1), axis=0)[0:len(data_train[y_b])],data_train[y_b])
    best_clf=clf.best_estimator_
    y_valid=best_clf.predict(data_original[new_column_list].div(data_original[new_column_list].sum(axis=1), axis=0)[len(data_train[y_b]):])
    report_selected2 = classification_report(data_val[y_b],y_valid,output_dict=True)
    dfselected2=pd.DataFrame(report_selected2).transpose()
    dfselected=pd.merge(dfselected1,dfselected2,on=dfselected2.index)

    #Clustering
    kmeans = KMeans(n_clusters=2, random_state=0).fit(data[x_column_list])
    report_k_means= classification_report(data[y_b],kmeans.labels_,output_dict=True)
    dK_means=pd.DataFrame(report_k_means).transpose()
    dK_means['key_0']=dK_means.index
    c_1=pd.merge(dRF,dAll,on=dRF.index)
    c_2=pd.merge(c_1,dK_means,on='key_0')
    c_3=pd.merge(c_2,dfselected,on='key_0')
    coln=['class','precision_RF','recall_RF','f1_RF','support_RF','precision_All','recall_All','f1_All','support_All','precision_k-m','recall_k-m','f1-score_k-m','support_k-m','precision_selected1','recall_selected1','f1-score_selected1','support_selected1','precision_selected2','recall_selected2','f1-score_selected2','support_selected2']
    c_3.columns=coln
    #####conclusion
    f1_cols = [col for col in c_3.columns if 'f1' in col]
    c_f1_t=c_3[f1_cols]
    c_f1=pd.DataFrame(c_f1_t.iloc[4,:])
    c_f1.rename(columns={4:'f1'}, inplace=True)
    namemethod=c_f1['f1'].idxmax()
    c_f1_t.index=dRF.index
    f_0=c_f1_t[namemethod][0]
    f_1=c_f1_t[namemethod][1]
    BestF=[f_0,f_1]
    F1_0_class_RF=c_3.iloc[0,3]
    F1_1_class_RF=c_3.iloc[1,3]
    return percent_label,featureDf, c_3,c_f1_t

# %%
df1=pd.read_csv("/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/binary-data.csv")
df2 = pd.read_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/metadata.csv')
df1=df1.drop('Variety2',axis=1)
df1.rename(columns={'Yield_per_plant':"y_binary"}, inplace=True)
df2 = df2[['Unnamed: 0', 'Yield_per_plant']]
df2.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)
data_original = pd.merge(df1, df2, on='Link_ID')
n_train=180
cv=RepeatedKFold(n_splits=10,n_repeats=3, random_state=100)
th=0.05
NumofR=2
q=0.7
os.chdir('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data')
path = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data'
file_list = []
for file in os.listdir(path):
    if (file[0] != 'R') & (file[-4:] == '.csv'):
        file_list.append(file[-4:]) 
output_dic = dict.fromkeys(file_list)
for file in os.listdir(path):
    if file[-4:] == '.csv':
        print(file)
        data_temp = pd.read_csv(file)
        output = process_data(data_original,data_temp,n_train,cv,q,NumofR)
        output_dic[file] = [output[0],output[1], output[2],output[3]]
# Out:
#  1 _ 3 .csv
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13558.165113829076, tolerance: 7042.5698921573
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14260.625899933279, tolerance: 7511.858413411847
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57463.60635469109, tolerance: 7441.089847525062
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86544.16568313539, tolerance: 7441.089847525062
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10234.99203568697, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23016.718038633466, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86830.18714997917, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25049.160512328148, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11754.228330627084, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8517.814034126699, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8262.561132505536, tolerance: 7590.328382494567
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8257.78155387193, tolerance: 7423.755868466223
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9870.76726628095, tolerance: 7423.755868466223
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10695.945491813123, tolerance: 7423.755868466223
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49961.95588526875, tolerance: 6862.343059800637
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40899.64752636105, tolerance: 6862.343059800637
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13096.471801698208, tolerance: 6862.343059800637
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18804.23524429649, tolerance: 6665.929766861808
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11024.323839746416, tolerance: 7117.469181020909
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30164.502345472574, tolerance: 7117.469181020909
#   model = cd_fast.enet_coordinate_descent_gram(
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7928.914048559964, tolerance: 7376.778631917951
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41930.1205034703, tolerance: 7376.778631917951
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8497.387377992272, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9003.26245571673, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9859.807711601257, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161236.50526940078, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274126.67526925355, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19079.34445936978, tolerance: 7529.328928369794
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10937.656029641628, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15086.268625959754, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7914.393978871405, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8133.284732684493, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64745.34628827125, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29500.95628386736, tolerance: 7236.438456742713
#   model = cd_fast.enet_coordinate_descent_gram(
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = '-'
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf['Count'][feature] += 1
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = 'X'
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 371, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 782, in _validate_y_class_weight
#     raise ValueError(
# ValueError: Valid presets for class_weight include "balanced" and "balanced_subsample".Given "auto".
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.51458446 0.52021827        nan        nan]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.50418339 0.52516771 0.33832844 0.4062705  0.40289065 0.40289065
#  0.40289065        nan        nan        nan        nan 0.4818665
#  0.51582397 0.52192416 0.53970211 0.50961783 0.50156336 0.53433901
#  0.52070658 0.52670727 0.52290519 0.52841594 0.52589367 0.49451265
#  0.50560395 0.50513331 0.49566014 0.50614017 0.50706898 0.51287988
#  0.52499913]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.45826576 0.46861974 0.34740704 0.40289065 0.40289065 0.40289065
#  0.40289065        nan        nan        nan        nan 0.47587484
#  0.51474511 0.50829583 0.50235323 0.51238967 0.51034238 0.49163195
#  0.50865259 0.50002825 0.50940556 0.52609069 0.5198558  0.51734259
#  0.5192237  0.5379837  0.52084144 0.54052327 0.54068325 0.53080233
#  0.53521184]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.45446348 0.48331425 0.3419936  0.40203595 0.40289065 0.40289065
#  0.40289065        nan        nan        nan        nan 0.48894248
#  0.51378007 0.51739179 0.50991319 0.47428581 0.49784972 0.47619559
#  0.48167976 0.48162577 0.48861067 0.49494241 0.49705275 0.49548975
#  0.51240859 0.49277758 0.50077971 0.49701763 0.50279854 0.48926334
#  0.50069728]
#   warnings.warn(
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
#  4 _ 1 .csv
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24356.89170885086, tolerance: 6873.6336686312325
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39051.84469753504, tolerance: 6873.6336686312325
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57262.483559668064, tolerance: 7042.5698921573
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10755.341486759484, tolerance: 7329.728845466845
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13107.380445197225, tolerance: 7329.728845466845
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6929.7445647493005, tolerance: 6802.82363083671
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6893.337195187807, tolerance: 6802.82363083671
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15317.927154384553, tolerance: 7511.858413411847
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11868.763696029782, tolerance: 7095.584963007412
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11780.499991059303, tolerance: 7095.584963007412
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16291.665578976274, tolerance: 6665.929766861808
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19505.60312897712, tolerance: 6665.929766861808
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20260.80016051978, tolerance: 6665.929766861808
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10096.09809730202, tolerance: 7482.214781370746
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83897.24177391827, tolerance: 7482.214781370746
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177354.66658369452, tolerance: 7482.214781370746
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 278823.36915519834, tolerance: 7482.214781370746
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 382543.7641820684, tolerance: 7482.214781370746
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31147.826040886343, tolerance: 7117.469181020909
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44328.524019911885, tolerance: 7117.469181020909
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138132.46754390746, tolerance: 7433.396571082564
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125895.70303881913, tolerance: 7433.396571082564
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10592.217341594398, tolerance: 7373.501117379994
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51070.08748289943, tolerance: 7373.501117379994
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187332.18453080952, tolerance: 7373.501117379994
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160767.69009937346, tolerance: 7373.501117379994
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136796.82553181052, tolerance: 7373.501117379994
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7718.168627344072, tolerance: 7376.778631917951
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6727.112756744027, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6828.188584692776, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16715.434442423284, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84266.82599653304, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181474.82445322722, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274426.00188946724, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10280.600063666701, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8981.487943410873, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8844.814621791244, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8779.17995543778, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8550.052592679858, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17210.874138504267, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48321.18973596394, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf['Count'][feature] += 1
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = 'X'
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = '-'
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 371, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 782, in _validate_y_class_weight
#     raise ValueError(
# ValueError: Valid presets for class_weight include "balanced" and "balanced_subsample".Given "auto".
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.51398171 0.50378817        nan        nan]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.53156683 0.50363454 0.40325557 0.3585287  0.30963981 0.32189725
#  0.41991761        nan        nan        nan        nan 0.46252095
#  0.47069766 0.46497437 0.48520177 0.47644041 0.48031146 0.47706539
#  0.47126069 0.49314334 0.51080302 0.52822567 0.51188488 0.53255517
#  0.52084613 0.51413537 0.50241129 0.50470054 0.5060976  0.51087161
#  0.52067857]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.51740563 0.5146425  0.41996213 0.35760916 0.30963981 0.31918789
#  0.41816376        nan        nan        nan        nan 0.4695169
#  0.46972559 0.48178433 0.48735711 0.47980619 0.48042851 0.47263259
#  0.46378213 0.49123644 0.51576583 0.5222782  0.51378428 0.52115797
#  0.51237337 0.5033981  0.49749706 0.50251556 0.51643528 0.5169985
#  0.53030746]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.52132001 0.52648182 0.36244655 0.4062705  0.40289065 0.40289065
#  0.40289065        nan        nan        nan        nan 0.4809785
#  0.51103401 0.52532712 0.53339559 0.52489708 0.5284317  0.53172967
#  0.51695841 0.52897382 0.5296304  0.52790741 0.52808262 0.50805166
#  0.52083812 0.51776139 0.50727431 0.49661364 0.50289493 0.50064456
#  0.52931166]
#   warnings.warn(
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
#  5 _ 1 .csv
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/2114219913.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_pval = pd.Series(index=remaining_features)
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22858.041604682803, tolerance: 6420.567785408484
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106543.69852526486, tolerance: 6971.32216688509
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203085.77181896567, tolerance: 7529.328928369794
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40093.818612866104, tolerance: 7529.328928369794
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164616.6660919264, tolerance: 7529.328928369794
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11162.277054563165, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34394.53965448588, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20274.241601251066, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21743.419271975756, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120076.2975057438, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219396.25165233016, tolerance: 7320.9402406100935
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9841.619196668267, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38495.091340497136, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9018.645149968565, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173868.0420909673, tolerance: 7670.77220974021
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36207.57952135056, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64490.78125669062, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81435.9711913839, tolerance: 7461.62514582779
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15004.939408749342, tolerance: 7236.438456742713
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41861.46546263248, tolerance: 7236.438456742713
#   model = cd_fast.enet_coordinate_descent_gram(
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# Fitting 30 folds for each of 36 candidates, totalling 1080 fits
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf['Count'][feature] += 1
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = 'X'
# /var/folders/96/yh0jxgf16t5_3vj4pfcbh3ph0000gn/T/ipykernel_94416/805479879.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   featureDf[method][feature] = '-'
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 371, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 782, in _validate_y_class_weight
#     raise ValueError(
# ValueError: Valid presets for class_weight include "balanced" and "balanced_subsample".Given "auto".
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.51812514 0.54088011        nan        nan]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.52008986 0.46622041 0.41381194 0.35577008 0.33224517 0.34476768
#  0.34747293        nan        nan        nan        nan 0.46485709
#  0.45559572 0.46995829 0.45519742 0.47346637 0.4531176  0.48342729
#  0.47937136 0.50001495 0.48664704 0.48457034 0.49778745 0.50986203
#  0.49341313 0.51005854 0.49019636 0.49946616 0.49056318 0.49801487
#  0.5053063 ]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.49775381 0.47357169 0.41152761 0.35577008 0.33224517 0.34515441
#  0.35423147        nan        nan        nan        nan 0.46254502
#  0.44853854 0.47275541 0.45820804 0.46049462 0.45494212 0.47918619
#  0.46614674 0.49411088 0.50463651 0.49616285 0.5058276  0.51249045
#  0.50205715 0.52177754 0.51122139 0.51081138 0.4880244  0.50449525
#  0.49286213]
#   warnings.warn(
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 120 fits failed out of a total of 930.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 182, in fit
#     y = self._validate_targets(y)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/svm/_base.py", line 737, in _validate_targets
#     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#   File "/Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/utils/class_weight.py", line 60, in compute_class_weight
#     raise ValueError(
# ValueError: class_weight must be dict, 'balanced', or None, got: 'auto'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/rosa/opt/anaconda3/envs/testEnv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.47677156 0.54095268 0.36360686 0.4062705  0.40289065 0.40289065
#  0.40289065        nan        nan        nan        nan 0.48541407
#  0.50134826 0.52063591 0.54803567 0.51425086 0.51005572 0.52951076
#  0.52618903 0.5317741  0.52518733 0.51771161 0.52285243 0.50963168
#  0.52041803 0.50705021 0.50790722 0.50092494 0.51899458 0.51589861
#  0.53349716]
#   warnings.warn(

# %%
t=pd.DataFrame(output_dic[file][3]['f1_RF'])

# %%
t
# Out:
#                  f1_RF
# 0.0           0.457143
# 1.0           0.558140
# accuracy      0.512821
# macro avg     0.507641
# weighted avg  0.495988

# %%
output_dic
# Out:
# {'.csv': None,
#  ' 1 _ 3 .csv': [[48, 62],
#                     Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria         X     X                   X        X   X
#   Cyanobacteria           X     X                   X        X   -
#   Proteobacteria          X     X                   -        X   X
#   Chloroflexi             X     X                   -        X   -
#   Myxococcota             X     X                   -        -   X
#   Methylomirabilota       X     X                   X        -   -
#   Bacteroidota            X     -                   -        -   -
#   Actinobacteriota        X     X                   -        X   -
#   Firmicutes              X     -                   -        X   X
#   Gemmatimonadota         X     -                   -        -   X
#   Hydrogenedentes         -     X                   -        -   X
#   Acidobacteriota         X     -                   -        X   X
#   Verrucomicrobiota       X     -                   -        X   -
#   WPS.2                   -     X                   -        -   -
#   Sumerlaeota             -     -                   -        -   X
#   Spirochaetota           -     X                   -        -   -
#   Nitrospirota            X     -                   -        -   -
#   Nanoarchaeota           -     X                   -        -   -
#   NA_1                    -     X                   -        -   -
#   Latescibacterota        -     X                   -        -   -
#   WS2                     -     -                   -        -   X
#   MBNT15                  -     X                   -        -   -
#   Halobacterota           -     X                   -        -   -
#   FCPU426                 -     X                   -        -   -
#   Elusimicrobiota         -     -                   -        -   X
#   Fibrobacterota          -     X                   -        -   -
#   Planctomycetota         -     X                   -        -   -
#   RCP2.54                 -     -                   -        -   -
#   Desulfobacterota        -     -                   -        -   X
#   Dependentiae            -     X                   -        -   -
#   Sva0485                 -     X                   -        -   -
#   Crenarchaeota           -     -                   -        -   X
#   Bdellovibrionota        -     -                   -        -   -
#   Abditibacteriota        -     -                   -        -   X
#
#                     Random Forest Mutual Info  Count
#   Patescibacteria               X           X      7
#   Cyanobacteria                 X           X      6
#   Proteobacteria                X           -      5
#   Chloroflexi                   -           X      4
#   Myxococcota                   X           -      4
#   Methylomirabilota             -           X      4
#   Bacteroidota                  X           X      3
#   Actinobacteriota              -           -      3
#   Firmicutes                    -           -      3
#   Gemmatimonadota               X           -      3
#   Hydrogenedentes               -           X      3
#   Acidobacteriota               -           -      3
#   Verrucomicrobiota             -           -      2
#   WPS.2                         -           X      2
#   Sumerlaeota                   X           -      2
#   Spirochaetota                 -           X      2
#   Nitrospirota                  -           X      2
#   Nanoarchaeota                 -           X      2
#   NA_1                          X           -      2
#   Latescibacterota              X           -      2
#   WS2                           X           -      2
#   MBNT15                        -           X      2
#   Halobacterota                 -           X      2
#   FCPU426                       X           -      2
#   Elusimicrobiota               X           -      2
#   Fibrobacterota                -           -      1
#   Planctomycetota               -           -      1
#   RCP2.54                       -           X      1
#   Desulfobacterota              -           -      1
#   Dependentiae                  -           -      1
#   Sva0485                       -           -      1
#   Crenarchaeota                 -           -      1
#   Bdellovibrionota              X           -      1
#   Abditibacteriota              -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.714286   0.416667  0.526316   24.000000       0.625000
#   1           1.0      0.440000   0.733333  0.550000   15.000000       0.391304
#   2      accuracy      0.538462   0.538462  0.538462    0.538462       0.487179
#   3     macro avg      0.577143   0.575000  0.538158   39.000000       0.508152
#   4  weighted avg      0.608791   0.538462  0.535425   39.000000       0.535117
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.416667  0.500000    24.000000       0.458333  ...      0.425121
#   1    0.600000  0.473684    15.000000       0.455285  ...      0.484848
#   2    0.487179  0.487179     0.487179       0.456621  ...      0.456621
#   3    0.508333  0.486842    39.000000       0.456809  ...      0.454985
#   4    0.487179  0.489879    39.000000       0.456830  ...      0.454576
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.500000          0.125000            0.200000
#   1   108.000000             0.363636          0.800000            0.500000
#   2     0.456621             0.384615          0.384615            0.384615
#   3   219.000000             0.431818          0.462500            0.350000
#   4   219.000000             0.447552          0.384615            0.315385
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.647059          0.458333
#   1          15.000000             0.409091          0.600000
#   2           0.384615             0.512821          0.512821
#   3          39.000000             0.528075          0.529167
#   4          39.000000             0.555533          0.512821
#
#      f1-score_selected2  support_selected2
#   0            0.536585          24.000000
#   1            0.486486          15.000000
#   2            0.512821           0.512821
#   3            0.511536          39.000000
#   4            0.517317          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.526316  0.500000      0.425121            0.200000
#   1.0           0.550000  0.473684      0.484848            0.500000
#   accuracy      0.538462  0.487179      0.456621            0.384615
#   macro avg     0.538158  0.486842      0.454985            0.350000
#   weighted avg  0.535425  0.489879      0.454576            0.315385
#
#                 f1-score_selected2
#   0.0                     0.536585
#   1.0                     0.486486
#   accuracy                0.512821
#   macro avg               0.511536
#   weighted avg            0.517317  ],
#  ' 4 _ 1 .csv': [[48, 62],
#                                Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria                    X     X                   X        X   X
#   Bacteroidota                       X     X                   -        -   X
#   Gemmatimonadota                    X     X                   -        -   X
#   Chloroflexi                        X     X                   -        -   X
#   Firmicutes                         X     -                   X        X   X
#   Acidobacteriota                    X     -                   -        X   X
#   Actinobacteriota                   X     -                   -        X   X
#   Proteobacteria                     X     -                   -        X   X
#   Verrucomicrobiota                  X     -                   -        X   X
#   Dependentiae                       -     X                   -        -   X
#   Myxococcota                        X     -                   -        -   X
#   Cyanobacteria                      X     -                   -        X   -
#   WPS.2                              -     X                   -        -   X
#   Methylomirabilota                  X     X                   -        -   -
#   Spirochaetota                      -     X                   -        -   -
#   Nitrospirota                       X     -                   -        -   -
#   Nanoarchaeota                      -     X                   -        -   -
#   NA_1                               -     X                   -        -   -
#   Zixibacteria                       -     X                   -        -   -
#   GAL15                              -     X                   X        -   -
#   FCPU426                            -     X                   -        -   -
#   Desulfobacterota                   -     X                   -        -   -
#   Latescibacterota                   -     X                   -        -   -
#   NB1.j                              -     X                   -        -   -
#   Hydrogenedentes                    -     -                   X        -   -
#   Nitrospinota                       -     X                   -        -   -
#   SAR324.clade.Marine.group.B.       -     -                   X        -   -
#   Deinococcota                       -     X                   -        -   -
#   Sva0485                            -     X                   -        -   -
#   Bdellovibrionota                   -     -                   -        -   -
#   Armatimonadota                     -     -                   -        -   X
#   MBNT15                             -     X                   -        -   -
#
#                                Random Forest Mutual Info  Count
#   Patescibacteria                          X           X      7
#   Bacteroidota                             X           X      5
#   Gemmatimonadota                          X           X      5
#   Chloroflexi                              X           X      5
#   Firmicutes                               X           -      5
#   Acidobacteriota                          X           -      4
#   Actinobacteriota                         X           -      4
#   Proteobacteria                           X           -      4
#   Verrucomicrobiota                        X           -      4
#   Dependentiae                             -           X      3
#   Myxococcota                              X           -      3
#   Cyanobacteria                            X           -      3
#   WPS.2                                    -           X      3
#   Methylomirabilota                        -           X      3
#   Spirochaetota                            -           X      2
#   Nitrospirota                             X           -      2
#   Nanoarchaeota                            -           X      2
#   NA_1                                     -           X      2
#   Zixibacteria                             -           X      2
#   GAL15                                    -           -      2
#   FCPU426                                  -           X      2
#   Desulfobacterota                         -           X      2
#   Latescibacterota                         -           -      1
#   NB1.j                                    -           -      1
#   Hydrogenedentes                          -           -      1
#   Nitrospinota                             -           -      1
#   SAR324.clade.Marine.group.B.             -           -      1
#   Deinococcota                             -           -      1
#   Sva0485                                  -           -      1
#   Bdellovibrionota                         X           -      1
#   Armatimonadota                           -           -      1
#   MBNT15                                   -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.900000   0.375000  0.529412   24.000000       0.600000
#   1           1.0      0.482759   0.933333  0.636364   15.000000       0.379310
#   2      accuracy      0.589744   0.589744  0.589744    0.589744       0.435897
#   3     macro avg      0.691379   0.654167  0.582888   39.000000       0.489655
#   4  weighted avg      0.739523   0.589744  0.570547   39.000000       0.515119
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.250000  0.352941    24.000000       0.537313  ...      0.587755
#   1    0.733333  0.500000    15.000000       0.541176  ...      0.476684
#   2    0.435897  0.435897     0.435897       0.538813  ...      0.538813
#   3    0.491667  0.426471    39.000000       0.539245  ...      0.532220
#   4    0.435897  0.409502    39.000000       0.539218  ...      0.532980
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.500000          0.166667            0.250000
#   1   108.000000             0.354839          0.733333            0.478261
#   2     0.538813             0.384615          0.384615            0.384615
#   3   219.000000             0.427419          0.450000            0.364130
#   4   219.000000             0.444169          0.384615            0.337793
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.625000          0.416667
#   1          15.000000             0.391304          0.600000
#   2           0.384615             0.487179          0.487179
#   3          39.000000             0.508152          0.508333
#   4          39.000000             0.535117          0.487179
#
#      f1-score_selected2  support_selected2
#   0            0.500000          24.000000
#   1            0.473684          15.000000
#   2            0.487179           0.487179
#   3            0.486842          39.000000
#   4            0.489879          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.529412  0.352941      0.587755            0.250000
#   1.0           0.636364  0.500000      0.476684            0.478261
#   accuracy      0.589744  0.435897      0.538813            0.384615
#   macro avg     0.582888  0.426471      0.532220            0.364130
#   weighted avg  0.570547  0.409502      0.532980            0.337793
#
#                 f1-score_selected2
#   0.0                     0.500000
#   1.0                     0.473684
#   accuracy                0.487179
#   macro avg               0.486842
#   weighted avg            0.489879  ],
#  ' 5 _ 1 .csv': [[48, 62],
#                                Maximum KBest Stepwise Regression Lasso CV GBM  \
#   WS2                                -     X                   X        X   X
#   FCPU426                            -     X                   X        X   X
#   RCP2.54                            -     X                   X        X   X
#   Cyanobacteria                      X     X                   -        -   -
#   Dependentiae                       -     X                   -        -   X
#   Gemmatimonadota                    X     -                   -        -   X
#   Firmicutes                         X     -                   X        -   -
#   Patescibacteria                    X     -                   -        -   X
#   NA_1                               -     -                   -        -   X
#   Myxococcota                        X     -                   -        -   X
#   Methylomirabilota                  X     X                   -        -   -
#   Acidobacteriota                    X     X                   -        -   -
#   MBNT15                             -     X                   -        X   -
#   Fibrobacterota                     X     -                   X        X   -
#   Bdellovibrionota                   -     X                   -        -   X
#   Actinobacteriota                   X     X                   -        -   -
#   Halobacterota                      -     X                   -        -   -
#   Desulfobacterota                   -     -                   -        -   X
#   Chloroflexi                        X     -                   -        -   -
#   Bacteroidota                       X     -                   -        -   -
#   SAR324.clade.Marine.group.B.       -     X                   -        -   -
#   Proteobacteria                     X     X                   -        -   -
#   Planctomycetota                    -     -                   -        -   -
#   Verrucomicrobiota                  X     -                   -        -   -
#   Sva0485                            -     X                   -        -   -
#   Sumerlaeota                        -     -                   -        X   -
#   Spirochaetota                      -     X                   -        -   -
#   Nitrospinota                       -     X                   -        -   -
#   Armatimonadota                     -     -                   -        -   X
#   Nitrospirota                       -     X                   -        -   -
#   Elusimicrobiota                    -     -                   -        -   X
#   Nanoarchaeota                      -     X                   -        -   -
#   NA_2                               -     X                   -        -   -
#   Latescibacterota                   -     -                   -        X   -
#   Hydrogenedentes                    -     X                   -        -   -
#   Abditibacteriota                   -     -                   -        -   X
#
#                                Random Forest Mutual Info  Count
#   WS2                                      X           X      6
#   FCPU426                                  X           X      6
#   RCP2.54                                  -           -      4
#   Cyanobacteria                            X           X      4
#   Dependentiae                             X           X      4
#   Gemmatimonadota                          X           X      4
#   Firmicutes                               X           -      3
#   Patescibacteria                          X           -      3
#   NA_1                                     X           X      3
#   Myxococcota                              X           -      3
#   Methylomirabilota                        -           X      3
#   Acidobacteriota                          -           X      3
#   MBNT15                                   -           X      3
#   Fibrobacterota                           -           -      3
#   Bdellovibrionota                         X           -      3
#   Actinobacteriota                         -           X      3
#   Halobacterota                            -           X      2
#   Desulfobacterota                         -           X      2
#   Chloroflexi                              X           -      2
#   Bacteroidota                             X           -      2
#   SAR324.clade.Marine.group.B.             -           X      2
#   Proteobacteria                           -           -      2
#   Planctomycetota                          X           -      1
#   Verrucomicrobiota                        -           -      1
#   Sva0485                                  -           -      1
#   Sumerlaeota                              -           -      1
#   Spirochaetota                            -           -      1
#   Nitrospinota                             -           -      1
#   Armatimonadota                           -           -      1
#   Nitrospirota                             -           -      1
#   Elusimicrobiota                          -           -      1
#   Nanoarchaeota                            -           -      1
#   NA_2                                     -           -      1
#   Latescibacterota                         -           -      1
#   Hydrogenedentes                          -           -      1
#   Abditibacteriota                         -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.562500   0.375000  0.450000   24.000000       0.500000
#   1           1.0      0.347826   0.533333  0.421053   15.000000       0.320000
#   2      accuracy      0.435897   0.435897  0.435897    0.435897       0.384615
#   3     macro avg      0.455163   0.454167  0.435526   39.000000       0.410000
#   4  weighted avg      0.479933   0.435897  0.438866   39.000000       0.430769
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.291667  0.368421    24.000000       0.506329  ...      0.594796
#   1    0.533333  0.400000    15.000000       0.491803  ...      0.355030
#   2    0.384615  0.384615     0.384615       0.502283  ...      0.502283
#   3    0.412500  0.384211    39.000000       0.499066  ...      0.474913
#   4    0.384615  0.380567    39.000000       0.499166  ...      0.476555
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.800000          0.500000            0.615385
#   1   108.000000             0.500000          0.800000            0.615385
#   2     0.502283             0.615385          0.615385            0.615385
#   3   219.000000             0.650000          0.650000            0.615385
#   4   219.000000             0.684615          0.615385            0.615385
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.642857          0.375000
#   1          15.000000             0.400000          0.666667
#   2           0.615385             0.487179          0.487179
#   3          39.000000             0.521429          0.520833
#   4          39.000000             0.549451          0.487179
#
#      f1-score_selected2  support_selected2
#   0            0.473684          24.000000
#   1            0.500000          15.000000
#   2            0.487179           0.487179
#   3            0.486842          39.000000
#   4            0.483806          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.450000  0.368421      0.594796            0.615385
#   1.0           0.421053  0.400000      0.355030            0.615385
#   accuracy      0.435897  0.384615      0.502283            0.615385
#   macro avg     0.435526  0.384211      0.474913            0.615385
#   weighted avg  0.438866  0.380567      0.476555            0.615385
#
#                 f1-score_selected2
#   0.0                     0.473684
#   1.0                     0.500000
#   accuracy                0.487179
#   macro avg               0.486842
#   weighted avg            0.483806  ],
#  ' 1 _ 2 .csv': [[48, 62],
#                     Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria         X     X                   X        X   X
#   Firmicutes              X     -                   X        X   X
#   RCP2.54                 -     X                   -        -   X
#   Actinobacteriota        X     X                   -        X   X
#   Chloroflexi             X     X                   -        X   -
#   Myxococcota             X     X                   -        -   X
#   Cyanobacteria           X     X                   -        X   -
#   Methylomirabilota       X     X                   X        -   -
#   FCPU426                 -     X                   -        -   X
#   Proteobacteria          X     X                   -        X   -
#   Latescibacterota        -     X                   X        -   -
#   NA_1                    -     X                   -        -   -
#   Acidobacteriota         X     -                   -        X   X
#   Fibrobacterota          -     X                   -        -   X
#   Gemmatimonadota         X     -                   -        -   X
#   Elusimicrobiota         -     X                   -        -   X
#   WS2                     -     -                   X        -   X
#   Thermoplasmatota        -     X                   -        -   -
#   Verrucomicrobiota       X     -                   -        X   -
#   WPS.2                   -     X                   X        -   -
#   Spirochaetota           -     X                   -        -   -
#   MBNT15                  -     X                   -        -   -
#   Zixibacteria            -     X                   -        -   -
#   Nitrospirota            X     -                   -        -   -
#   Bacteroidota            X     -                   -        -   -
#   Planctomycetota         -     X                   -        -   -
#   Dependentiae            -     X                   -        -   -
#   Crenarchaeota           -     -                   -        -   X
#   Bdellovibrionota        -     -                   -        -   -
#   Abditibacteriota        -     -                   -        -   X
#
#                     Random Forest Mutual Info  Count
#   Patescibacteria               X           X      7
#   Firmicutes                    X           -      5
#   RCP2.54                       X           X      4
#   Actinobacteriota              -           -      4
#   Chloroflexi                   -           X      4
#   Myxococcota                   X           -      4
#   Cyanobacteria                 -           X      4
#   Methylomirabilota             -           X      4
#   FCPU426                       X           X      4
#   Proteobacteria                X           -      4
#   Latescibacterota              X           -      3
#   NA_1                          X           X      3
#   Acidobacteriota               -           -      3
#   Fibrobacterota                X           -      3
#   Gemmatimonadota               X           -      3
#   Elusimicrobiota               X           -      3
#   WS2                           X           -      3
#   Thermoplasmatota              -           X      2
#   Verrucomicrobiota             -           -      2
#   WPS.2                         -           -      2
#   Spirochaetota                 -           X      2
#   MBNT15                        -           X      2
#   Zixibacteria                  -           X      2
#   Nitrospirota                  -           X      2
#   Bacteroidota                  -           X      2
#   Planctomycetota               -           -      1
#   Dependentiae                  -           -      1
#   Crenarchaeota                 -           -      1
#   Bdellovibrionota              X           -      1
#   Abditibacteriota              -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.687500   0.458333  0.550000   24.000000       0.642857
#   1           1.0      0.434783   0.666667  0.526316   15.000000       0.400000
#   2      accuracy      0.538462   0.538462  0.538462    0.538462       0.487179
#   3     macro avg      0.561141   0.562500  0.538158   39.000000       0.521429
#   4  weighted avg      0.590301   0.538462  0.540891   39.000000       0.549451
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.375000  0.473684    24.000000       0.458333  ...      0.425121
#   1    0.666667  0.500000    15.000000       0.455285  ...      0.484848
#   2    0.487179  0.487179     0.487179       0.456621  ...      0.456621
#   3    0.520833  0.486842    39.000000       0.456809  ...      0.454985
#   4    0.487179  0.483806    39.000000       0.456830  ...      0.454576
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.571429          0.333333            0.421053
#   1   108.000000             0.360000          0.600000            0.450000
#   2     0.456621             0.435897          0.435897            0.435897
#   3   219.000000             0.465714          0.466667            0.435526
#   4   219.000000             0.490110          0.435897            0.432186
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.400000          0.083333
#   1          15.000000             0.352941          0.800000
#   2           0.435897             0.358974          0.358974
#   3          39.000000             0.376471          0.441667
#   4          39.000000             0.381900          0.358974
#
#      f1-score_selected2  support_selected2
#   0            0.137931          24.000000
#   1            0.489796          15.000000
#   2            0.358974           0.358974
#   3            0.313863          39.000000
#   4            0.273264          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.550000  0.473684      0.425121            0.421053
#   1.0           0.526316  0.500000      0.484848            0.450000
#   accuracy      0.538462  0.487179      0.456621            0.435897
#   macro avg     0.538158  0.486842      0.454985            0.435526
#   weighted avg  0.540891  0.483806      0.454576            0.432186
#
#                 f1-score_selected2
#   0.0                     0.137931
#   1.0                     0.489796
#   accuracy                0.358974
#   macro avg               0.313863
#   weighted avg            0.273264  ],
#  ' 1 _ 4 .csv': [[48, 62],
#                                Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria                    X     X                   -        X   X
#   Methylomirabilota                  X     X                   X        -   -
#   Firmicutes                         X     -                   X        X   X
#   Bacteroidota                       X     -                   -        X   X
#   Proteobacteria                     X     X                   -        X   -
#   Chloroflexi                        X     X                   -        X   -
#   Cyanobacteria                      X     X                   -        X   -
#   FCPU426                            -     X                   -        -   X
#   Acidobacteriota                    X     -                   -        X   X
#   Latescibacterota                   -     X                   X        -   X
#   Hydrogenedentes                    -     X                   -        -   X
#   Gemmatimonadota                    X     -                   -        -   X
#   WS2                                -     -                   X        -   X
#   Verrucomicrobiota                  X     -                   X        X   -
#   Elusimicrobiota                    -     X                   -        -   X
#   NB1.j                              -     X                   X        -   -
#   Myxococcota                        X     -                   -        -   -
#   NA_1                               -     -                   -        -   -
#   Nitrospirota                       X     -                   -        -   -
#   Spirochaetota                      -     X                   -        -   -
#   MBNT15                             -     X                   -        -   -
#   Halobacterota                      -     X                   -        -   -
#   Dependentiae                       -     X                   -        -   -
#   Crenarchaeota                      -     X                   -        -   X
#   Actinobacteriota                   X     -                   -        X   -
#   Fibrobacterota                     -     X                   -        -   -
#   Nanoarchaeota                      -     X                   -        -   -
#   Nitrospinota                       -     X                   -        -   -
#   Bdellovibrionota                   -     -                   -        -   -
#   RCP2.54                            -     -                   -        -   -
#   SAR324.clade.Marine.group.B.       -     -                   -        -   -
#   Armatimonadota                     -     -                   -        -   X
#   Sumerlaeota                        -     -                   -        -   -
#   Sva0485                            -     X                   -        -   -
#   WPS.2                              -     X                   -        -   -
#   Abditibacteriota                   -     -                   -        -   X
#
#                                Random Forest Mutual Info  Count
#   Patescibacteria                          X           X      6
#   Methylomirabilota                        X           X      5
#   Firmicutes                               -           -      4
#   Bacteroidota                             -           X      4
#   Proteobacteria                           X           -      4
#   Chloroflexi                              -           X      4
#   Cyanobacteria                            -           X      4
#   FCPU426                                  X           X      4
#   Acidobacteriota                          -           -      3
#   Latescibacterota                         -           -      3
#   Hydrogenedentes                          X           -      3
#   Gemmatimonadota                          X           -      3
#   WS2                                      X           -      3
#   Verrucomicrobiota                        -           -      3
#   Elusimicrobiota                          -           X      3
#   NB1.j                                    -           -      2
#   Myxococcota                              X           -      2
#   NA_1                                     X           X      2
#   Nitrospirota                             -           X      2
#   Spirochaetota                            -           X      2
#   MBNT15                                   -           X      2
#   Halobacterota                            -           X      2
#   Dependentiae                             X           -      2
#   Crenarchaeota                            -           -      2
#   Actinobacteriota                         -           -      2
#   Fibrobacterota                           -           -      1
#   Nanoarchaeota                            -           -      1
#   Nitrospinota                             -           -      1
#   Bdellovibrionota                         X           -      1
#   RCP2.54                                  -           X      1
#   SAR324.clade.Marine.group.B.             X           -      1
#   Armatimonadota                           -           -      1
#   Sumerlaeota                              X           -      1
#   Sva0485                                  -           -      1
#   WPS.2                                    -           -      1
#   Abditibacteriota                         -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.785714   0.458333  0.578947   24.000000       0.615385
#   1           1.0      0.480000   0.800000  0.600000   15.000000       0.384615
#   2      accuracy      0.589744   0.589744  0.589744    0.589744       0.461538
#   3     macro avg      0.632857   0.629167  0.589474   39.000000       0.500000
#   4  weighted avg      0.668132   0.589744  0.587045   39.000000       0.526627
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.333333  0.432432    24.000000       0.458333  ...      0.425121
#   1    0.666667  0.487805    15.000000       0.455285  ...      0.484848
#   2    0.461538  0.461538     0.461538       0.456621  ...      0.456621
#   3    0.500000  0.460119    39.000000       0.456809  ...      0.454985
#   4    0.461538  0.453730    39.000000       0.456830  ...      0.454576
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.750000          0.250000            0.375000
#   1   108.000000             0.419355          0.866667            0.565217
#   2     0.456621             0.487179          0.487179            0.487179
#   3   219.000000             0.584677          0.558333            0.470109
#   4   219.000000             0.622829          0.487179            0.448161
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.818182          0.375000
#   1          15.000000             0.464286          0.866667
#   2           0.487179             0.564103          0.564103
#   3          39.000000             0.641234          0.620833
#   4          39.000000             0.682068          0.564103
#
#      f1-score_selected2  support_selected2
#   0            0.514286          24.000000
#   1            0.604651          15.000000
#   2            0.564103           0.564103
#   3            0.559468          39.000000
#   4            0.549042          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.578947  0.432432      0.425121            0.375000
#   1.0           0.600000  0.487805      0.484848            0.565217
#   accuracy      0.589744  0.461538      0.456621            0.487179
#   macro avg     0.589474  0.460119      0.454985            0.470109
#   weighted avg  0.587045  0.453730      0.454576            0.448161
#
#                 f1-score_selected2
#   0.0                     0.514286
#   1.0                     0.604651
#   accuracy                0.564103
#   macro avg               0.559468
#   weighted avg            0.549042  ],
#  ' 3 _ 1 .csv': [[48, 62],
#                                Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria                    X     X                   -        X   X
#   Firmicutes                         X     -                   X        X   X
#   Bacteroidota                       X     -                   -        X   X
#   Proteobacteria                     X     X                   -        X   X
#   Elusimicrobiota                    -     X                   -        -   X
#   Cyanobacteria                      X     X                   -        X   -
#   Acidobacteriota                    X     -                   -        X   X
#   FCPU426                            -     X                   -        -   X
#   Methylomirabilota                  X     X                   X        -   -
#   Chloroflexi                        X     X                   -        X   -
#   Gemmatimonadota                    X     -                   -        -   X
#   NA_1                               -     X                   -        -   -
#   Latescibacterota                   -     X                   X        -   -
#   Verrucomicrobiota                  X     -                   X        X   -
#   WS2                                -     -                   X        -   X
#   Myxococcota                        X     -                   -        -   -
#   Nitrospirota                       X     -                   -        -   -
#   Spirochaetota                      -     X                   -        -   -
#   Nanoarchaeota                      -     X                   -        -   -
#   MBNT15                             -     X                   -        -   -
#   Hydrogenedentes                    -     X                   -        -   -
#   Crenarchaeota                      -     X                   -        -   X
#   Actinobacteriota                   X     -                   -        X   -
#   NB1.j                              -     -                   X        -   -
#   Halobacterota                      -     X                   -        -   -
#   Nitrospinota                       -     X                   -        -   -
#   Fibrobacterota                     -     X                   -        -   -
#   Bdellovibrionota                   -     -                   -        -   -
#   RCP2.54                            -     -                   -        -   X
#   SAR324.clade.Marine.group.B.       -     -                   -        -   X
#   Armatimonadota                     -     X                   -        -   -
#   Sva0485                            -     X                   -        -   -
#   WPS.2                              -     X                   -        -   -
#   Abditibacteriota                   -     -                   -        -   X
#
#                                Random Forest Mutual Info  Count
#   Patescibacteria                          X           X      6
#   Firmicutes                               X           -      5
#   Bacteroidota                             X           X      5
#   Proteobacteria                           X           -      5
#   Elusimicrobiota                          X           X      4
#   Cyanobacteria                            -           X      4
#   Acidobacteriota                          X           -      4
#   FCPU426                                  X           X      4
#   Methylomirabilota                        -           X      4
#   Chloroflexi                              -           X      4
#   Gemmatimonadota                          X           -      3
#   NA_1                                     X           X      3
#   Latescibacterota                         X           -      3
#   Verrucomicrobiota                        -           -      3
#   WS2                                      X           -      3
#   Myxococcota                              X           -      2
#   Nitrospirota                             -           X      2
#   Spirochaetota                            -           X      2
#   Nanoarchaeota                            -           X      2
#   MBNT15                                   -           X      2
#   Hydrogenedentes                          -           X      2
#   Crenarchaeota                            -           -      2
#   Actinobacteriota                         -           -      2
#   NB1.j                                    -           -      1
#   Halobacterota                            -           -      1
#   Nitrospinota                             -           -      1
#   Fibrobacterota                           -           -      1
#   Bdellovibrionota                         X           -      1
#   RCP2.54                                  -           -      1
#   SAR324.clade.Marine.group.B.             -           -      1
#   Armatimonadota                           -           -      1
#   Sva0485                                  -           -      1
#   WPS.2                                    -           -      1
#   Abditibacteriota                         -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.687500   0.458333  0.550000   24.000000       0.615385
#   1           1.0      0.434783   0.666667  0.526316   15.000000       0.384615
#   2      accuracy      0.538462   0.538462  0.538462    0.538462       0.461538
#   3     macro avg      0.561141   0.562500  0.538158   39.000000       0.500000
#   4  weighted avg      0.590301   0.538462  0.540891   39.000000       0.526627
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.333333  0.432432    24.000000       0.458333  ...      0.425121
#   1    0.666667  0.487805    15.000000       0.455285  ...      0.484848
#   2    0.461538  0.461538     0.461538       0.456621  ...      0.456621
#   3    0.500000  0.460119    39.000000       0.456809  ...      0.454985
#   4    0.461538  0.453730    39.000000       0.456830  ...      0.454576
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.800000          0.166667            0.275862
#   1   108.000000             0.411765          0.933333            0.571429
#   2     0.456621             0.461538          0.461538            0.461538
#   3   219.000000             0.605882          0.550000            0.423645
#   4   219.000000             0.650679          0.461538            0.389541
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.818182          0.375000
#   1          15.000000             0.464286          0.866667
#   2           0.461538             0.564103          0.564103
#   3          39.000000             0.641234          0.620833
#   4          39.000000             0.682068          0.564103
#
#      f1-score_selected2  support_selected2
#   0            0.514286          24.000000
#   1            0.604651          15.000000
#   2            0.564103           0.564103
#   3            0.559468          39.000000
#   4            0.549042          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.550000  0.432432      0.425121            0.275862
#   1.0           0.526316  0.487805      0.484848            0.571429
#   accuracy      0.538462  0.461538      0.456621            0.461538
#   macro avg     0.538158  0.460119      0.454985            0.423645
#   weighted avg  0.540891  0.453730      0.454576            0.389541
#
#                 f1-score_selected2
#   0.0                     0.514286
#   1.0                     0.604651
#   accuracy                0.564103
#   macro avg               0.559468
#   weighted avg            0.549042  ],
#  ' 2 _ 1 .csv': [[48, 62],
#                                Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Patescibacteria                    X     X                   X        X   X
#   Cyanobacteria                      X     X                   -        -   X
#   Firmicutes                         X     -                   X        X   -
#   Bacteroidota                       X     -                   -        -   X
#   NA_1                               -     X                   -        -   X
#   Methylomirabilota                  X     X                   -        -   X
#   Gemmatimonadota                    X     X                   -        X   -
#   FCPU426                            -     X                   -        -   X
#   MBNT15                             -     X                   X        -   -
#   Nitrospirota                       X     X                   -        -   -
#   Myxococcota                        X     -                   -        -   X
#   WS2                                -     -                   X        -   X
#   Actinobacteriota                   X     X                   -        -   -
#   Elusimicrobiota                    -     X                   -        -   -
#   Halobacterota                      -     X                   -        -   -
#   Verrucomicrobiota                  X     -                   -        -   X
#   Spirochaetota                      -     X                   -        -   -
#   RCP2.54                            -     -                   -        -   X
#   Proteobacteria                     X     -                   -        X   -
#   Planctomycetota                    -     X                   -        -   -
#   Abditibacteriota                   -     -                   -        -   X
#   Chloroflexi                        X     -                   -        X   -
# ...
#   2      accuracy      0.435897   0.435897  0.435897    0.435897       0.410256
#   3     macro avg      0.506048   0.504167  0.417120   39.000000       0.491176
#   4  weighted avg      0.533499   0.435897  0.392977   39.000000       0.516290
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.125000  0.206897    24.000000       0.426966  ...      0.380000
#   1    0.866667  0.530612    15.000000       0.438462  ...      0.478992
#   2    0.410256  0.410256     0.410256       0.433790  ...      0.433790
#   3    0.495833  0.368754    39.000000       0.432714  ...      0.429496
#   4    0.410256  0.331403    39.000000       0.432635  ...      0.428818
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0    111.00000             0.600000          0.125000            0.206897
#   1    108.00000             0.382353          0.866667            0.530612
#   2      0.43379             0.410256          0.410256            0.410256
#   3    219.00000             0.491176          0.495833            0.368754
#   4    219.00000             0.516290          0.410256            0.331403
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.625000          0.416667
#   1          15.000000             0.391304          0.600000
#   2           0.410256             0.487179          0.487179
#   3          39.000000             0.508152          0.508333
#   4          39.000000             0.535117          0.487179
#
#      f1-score_selected2  support_selected2
#   0            0.500000          24.000000
#   1            0.473684          15.000000
#   2            0.487179           0.487179
#   3            0.486842          39.000000
#   4            0.489879          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.312500  0.206897      0.380000            0.206897
#   1.0           0.521739  0.530612      0.478992            0.530612
#   accuracy      0.435897  0.410256      0.433790            0.410256
#   macro avg     0.417120  0.368754      0.429496            0.368754
#   weighted avg  0.392977  0.331403      0.428818            0.331403
#
#                 f1-score_selected2
#   0.0                     0.500000
#   1.0                     0.473684
#   accuracy                0.487179
#   macro avg               0.486842
#   weighted avg            0.489879  ],
#  ' 5 _ 2 .csv': [[48, 62],
#                     Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Firmicutes              X     X                   X        X   X
#   FCPU426                 -     X                   X        X   X
#   RCP2.54                 -     X                   X        X   X
#   Nitrospirota            X     X                   -        -   X
#   Sumerlaeota             -     X                   -        X   X
#   Proteobacteria          X     X                   -        -   -
#   Cyanobacteria           X     X                   -        -   X
#   Myxococcota             X     X                   -        -   X
#   Fibrobacterota          -     -                   X        X   X
#   Latescibacterota        -     -                   X        X   -
#   Verrucomicrobiota       X     X                   -        -   -
#   Patescibacteria         X     -                   -        -   X
#   WS2                     -     -                   X        X   -
#   Actinobacteriota        X     X                   -        -   -
#   Bacteroidota            X     -                   -        -   X
#   Gemmatimonadota         X     -                   -        -   -
#   Halobacterota           -     X                   -        -   -
#   Thermoplasmatota        -     X                   -        -   -
#   Armatimonadota          -     X                   -        -   -
#   Spirochaetota           -     X                   -        -   X
#   Crenarchaeota           -     X                   -        -   -
#   Dependentiae            -     X                   -        -   -
#   Desulfobacterota        -     X                   -        -   -
#   Methylomirabilota       X     X                   -        -   -
#   Abditibacteriota        -     X                   -        -   X
#   Nanoarchaeota           -     X                   -        -   -
#   Chloroflexi             X     -                   -        -   -
#   NA_1                    -     -                   -        -   X
#   MBNT15                  -     -                   -        X   -
#   Acidobacteriota         X     -                   -        -   -
#
#                     Random Forest Mutual Info  Count
#   Firmicutes                    X           X      7
#   FCPU426                       X           X      6
#   RCP2.54                       X           -      5
#   Nitrospirota                  X           X      5
#   Sumerlaeota                   -           X      4
#   Proteobacteria                X           X      4
#   Cyanobacteria                 -           X      4
#   Myxococcota                   X           -      4
#   Fibrobacterota                X           -      4
#   Latescibacterota              X           -      3
#   Verrucomicrobiota             -           X      3
#   Patescibacteria               X           -      3
#   WS2                           X           -      3
#   Actinobacteriota              -           X      3
#   Bacteroidota                  X           -      3
#   Gemmatimonadota               X           -      2
#   Halobacterota                 -           X      2
#   Thermoplasmatota              -           X      2
#   Armatimonadota                -           X      2
#   Spirochaetota                 -           -      2
#   Crenarchaeota                 -           X      2
#   Dependentiae                  X           -      2
#   Desulfobacterota              -           X      2
#   Methylomirabilota             -           -      2
#   Abditibacteriota              -           -      2
#   Nanoarchaeota                 -           -      1
#   Chloroflexi                   -           -      1
#   NA_1                          -           -      1
#   MBNT15                        -           -      1
#   Acidobacteriota               -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.625000   0.416667  0.500000   24.000000       0.545455
#   1           1.0      0.391304   0.600000  0.473684   15.000000       0.357143
#   2      accuracy      0.487179   0.487179  0.487179    0.487179       0.410256
#   3     macro avg      0.508152   0.508333  0.486842   39.000000       0.451299
#   4  weighted avg      0.535117   0.487179  0.489879   39.000000       0.473027
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.250000  0.342857    24.000000       0.470588  ...      0.408163
#   1    0.666667  0.465116    15.000000       0.470149  ...      0.520661
#   2    0.410256  0.410256     0.410256       0.470320  ...      0.470320
#   3    0.458333  0.403987    39.000000       0.470369  ...      0.464412
#   4    0.410256  0.389880    39.000000       0.470372  ...      0.463642
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0    111.00000             0.652174          0.625000            0.638298
#   1    108.00000             0.437500          0.466667            0.451613
#   2      0.47032             0.564103          0.564103            0.564103
#   3    219.00000             0.544837          0.545833            0.544955
#   4    219.00000             0.569607          0.564103            0.566496
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.692308          0.375000
#   1          15.000000             0.423077          0.733333
#   2           0.564103             0.512821          0.512821
#   3          39.000000             0.557692          0.554167
#   4          39.000000             0.588757          0.512821
#
#      f1-score_selected2  support_selected2
#   0            0.486486          24.000000
#   1            0.536585          15.000000
#   2            0.512821           0.512821
#   3            0.511536          39.000000
#   4            0.505755          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.500000  0.342857      0.408163            0.638298
#   1.0           0.473684  0.465116      0.520661            0.451613
#   accuracy      0.487179  0.410256      0.470320            0.564103
#   macro avg     0.486842  0.403987      0.464412            0.544955
#   weighted avg  0.489879  0.389880      0.463642            0.566496
#
#                 f1-score_selected2
#   0.0                     0.486486
#   1.0                     0.536585
#   accuracy                0.512821
#   macro avg               0.511536
#   weighted avg            0.505755  ],
#  ' 4 _ 2 .csv': [[48, 62],
#                     Maximum KBest Stepwise Regression Lasso CV GBM  \
#   Bacteroidota            X     X                   -        X   X
#   Patescibacteria         X     X                   -        X   X
#   Cyanobacteria           X     -                   X        X   X
#   Gemmatimonadota         X     X                   -        X   X
#   Firmicutes              X     -                   X        X   X
#   Methylomirabilota       X     X                   X        -   -
#   Verrucomicrobiota       X     -                   -        X   X
#   Proteobacteria          X     -                   -        X   X
#   Chloroflexi             X     X                   -        X   -
#   Nitrospirota            X     X                   -        -   -
#   Myxococcota             X     -                   -        -   X
#   Actinobacteriota        X     X                   -        X   -
#   Acidobacteriota         X     X                   -        X   -
#   Latescibacterota        -     -                   X        -   X
#   FCPU426                 -     -                   -        -   X
#   Elusimicrobiota         -     X                   -        -   X
#   NA_1                    -     X                   -        -   -
#   NB1.j                   -     X                   -        -   -
#   Desulfobacterota        -     -                   -        -   X
#   Crenarchaeota           -     X                   -        -   -
#   Fibrobacterota          -     -                   -        -   X
#   MBNT15                  -     X                   -        -   -
#   Entotheonellaeota       -     X                   -        -   -
#   Nitrospinota            -     X                   -        -   -
#   Planctomycetota         -     X                   -        -   -
#   Bdellovibrionota        -     -                   -        -   -
#   RCP2.54                 -     X                   -        -   -
#   Spirochaetota           -     X                   -        -   -
#   Armatimonadota          -     X                   -        -   -
#   WS2                     -     X                   -        -   -
#
#                     Random Forest Mutual Info  Count
#   Bacteroidota                  X           X      6
#   Patescibacteria               X           X      6
#   Cyanobacteria                 X           X      6
#   Gemmatimonadota               X           X      6
#   Firmicutes                    X           -      5
#   Methylomirabilota             X           X      5
#   Verrucomicrobiota             X           -      4
#   Proteobacteria                X           -      4
#   Chloroflexi                   -           X      4
#   Nitrospirota                  X           X      4
#   Myxococcota                   X           X      4
#   Actinobacteriota              X           -      4
#   Acidobacteriota               -           -      3
#   Latescibacterota              X           -      3
#   FCPU426                       -           X      2
#   Elusimicrobiota               -           -      2
#   NA_1                          -           X      2
#   NB1.j                         -           X      2
#   Desulfobacterota              X           -      2
#   Crenarchaeota                 -           X      2
#   Fibrobacterota                -           -      1
#   MBNT15                        -           -      1
#   Entotheonellaeota             -           -      1
#   Nitrospinota                  -           -      1
#   Planctomycetota               -           -      1
#   Bdellovibrionota              -           X      1
#   RCP2.54                       -           -      1
#   Spirochaetota                 -           -      1
#   Armatimonadota                -           -      1
#   WS2                           -           -      1  ,
#             class  precision_RF  recall_RF     f1_RF  support_RF  precision_All  \
#   0           0.0      0.727273   0.333333  0.457143   24.000000       0.750000
#   1           1.0      0.428571   0.800000  0.558140   15.000000       0.444444
#   2      accuracy      0.512821   0.512821  0.512821    0.512821       0.538462
#   3     macro avg      0.577922   0.566667  0.507641   39.000000       0.597222
#   4  weighted avg      0.612388   0.512821  0.495988   39.000000       0.632479
#
#      recall_All    f1_All  support_All  precision_k-m  ...  f1-score_k-m  \
#   0    0.375000  0.500000    24.000000       0.432099  ...      0.364583
#   1    0.800000  0.571429    15.000000       0.449275  ...      0.504065
#   2    0.538462  0.538462     0.538462       0.442922  ...      0.442922
#   3    0.587500  0.535714    39.000000       0.440687  ...      0.434324
#   4    0.538462  0.527473    39.000000       0.440569  ...      0.433369
#
#      support_k-m  precision_selected1  recall_selected1  f1-score_selected1  \
#   0   111.000000             0.666667          0.083333            0.148148
#   1   108.000000             0.388889          0.933333            0.549020
#   2     0.442922             0.410256          0.410256            0.410256
#   3   219.000000             0.527778          0.508333            0.348584
#   4   219.000000             0.559829          0.410256            0.302329
#
#      support_selected1  precision_selected2  recall_selected2  \
#   0          24.000000             0.588235          0.416667
#   1          15.000000             0.363636          0.533333
#   2           0.410256             0.461538          0.461538
#   3          39.000000             0.475936          0.475000
#   4          39.000000             0.501851          0.461538
#
#      f1-score_selected2  support_selected2
#   0            0.487805          24.000000
#   1            0.432432          15.000000
#   2            0.461538           0.461538
#   3            0.460119          39.000000
#   4            0.466508          39.000000
#
#   [5 rows x 21 columns],
#                    f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
#   0.0           0.457143  0.500000      0.364583            0.148148
#   1.0           0.558140  0.571429      0.504065            0.549020
#   accuracy      0.512821  0.538462      0.442922            0.410256
#   macro avg     0.507641  0.535714      0.434324            0.348584
#   weighted avg  0.495988  0.527473      0.433369            0.302329
#
#                 f1-score_selected2
#   0.0                     0.487805
#   1.0                     0.432432
#   accuracy                0.461538
#   macro avg               0.460119
#   weighted avg            0.466508  ]}

# %%
output_dic[file][3]['f1_RF'].values
# Out:
# array([0.45714286, 0.55813953, 0.51282051, 0.5076412 , 0.49598773])

# %%
TAll
# Out:
#                 f1_All    f1_All    f1_All    f1_All    f1_All    f1_All  \
# 0.0           0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 1.0           0.571429  0.571429  0.571429  0.571429  0.571429  0.571429
# accuracy      0.538462  0.538462  0.538462  0.538462  0.538462  0.538462
# macro avg     0.535714  0.535714  0.535714  0.535714  0.535714  0.535714
# weighted avg  0.527473  0.527473  0.527473  0.527473  0.527473  0.527473
#
#                 f1_All    f1_All    f1_All    f1_All    f1_All    f1_All  \
# 0.0           0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 1.0           0.571429  0.571429  0.571429  0.571429  0.571429  0.571429
# accuracy      0.538462  0.538462  0.538462  0.538462  0.538462  0.538462
# macro avg     0.535714  0.535714  0.535714  0.535714  0.535714  0.535714
# weighted avg  0.527473  0.527473  0.527473  0.527473  0.527473  0.527473
#
#                 f1_All    f1_All    f1_All    f1_All    f1_All    f1_All  \
# 0.0           0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 1.0           0.571429  0.571429  0.571429  0.571429  0.571429  0.571429
# accuracy      0.538462  0.538462  0.538462  0.538462  0.538462  0.538462
# macro avg     0.535714  0.535714  0.535714  0.535714  0.535714  0.535714
# weighted avg  0.527473  0.527473  0.527473  0.527473  0.527473  0.527473
#
#                 f1_All    f1_All
# 0.0           0.500000  0.500000
# 1.0           0.571429  0.571429
# accuracy      0.538462  0.538462
# macro avg     0.535714  0.535714
# weighted avg  0.527473  0.527473

# %%
tRF
# Out:
#                     0         1         2         3         4         5   \
# 0.0           0.526316  0.529412  0.450000  0.550000  0.578947  0.550000
# 1.0           0.550000  0.636364  0.421053  0.526316  0.600000  0.526316
# accuracy      0.538462  0.589744  0.435897  0.538462  0.589744  0.538462
# macro avg     0.538158  0.582888  0.435526  0.538158  0.589474  0.538158
# weighted avg  0.535425  0.570547  0.438866  0.540891  0.587045  0.540891
#
#                     6         7         8         9         10        11  \
# 0.0           0.487805  0.473684  0.444444  0.444444  0.615385  0.461538
# 1.0           0.432432  0.500000  0.523810  0.523810  0.615385  0.461538
# accuracy      0.461538  0.487179  0.487179  0.487179  0.615385  0.461538
# macro avg     0.460119  0.486842  0.484127  0.484127  0.615385  0.461538
# weighted avg  0.466508  0.483806  0.474969  0.474969  0.615385  0.461538
#
#                     12        13        14        15        16        17  \
# 0.0           0.294118  0.358974  0.600000  0.583333  0.450000  0.312500
# 1.0           0.454545  0.358974  0.578947  0.333333  0.421053  0.521739
# accuracy      0.384615  0.358974  0.589744  0.487179  0.435897  0.435897
# macro avg     0.374332  0.358974  0.589474  0.458333  0.435526  0.417120
# weighted avg  0.355821  0.358974  0.591903  0.487179  0.438866  0.392977
#
#                     18        19
# 0.0           0.500000  0.457143
# 1.0           0.473684  0.558140
# accuracy      0.487179  0.512821
# macro avg     0.486842  0.507641
# weighted avg  0.489879  0.495988

# %%
#output_dic.items()
tRF=pd.DataFrame()
tALL=pd.DataFrame()
k=0
for key in output_dic.keys():
    if key != '.csv':
        print(key)
        print(output_dic[key][3])
        tRF[k]=pd.DataFrame(output_dic[key][3]['f1_RF'].values)
        tALL[k]=pd.DataFrame(output_dic[key][3]['f1_All'].values)
        k=k+1
tRF.index=output_dic[key][3].index
tALL.index=output_dic[key][3].index
tRF.to_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Report/totalF1_RFfor_randomizationmethods.csv')
tALL.to_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Report/totalF1_ALLfor_randomizationmethods.csv')
# Out:
#  1 _ 3 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.526316  0.500000      0.425121            0.200000
# 1.0           0.550000  0.473684      0.484848            0.500000
# accuracy      0.538462  0.487179      0.456621            0.384615
# macro avg     0.538158  0.486842      0.454985            0.350000
# weighted avg  0.535425  0.489879      0.454576            0.315385
#
#               f1-score_selected2
# 0.0                     0.536585
# 1.0                     0.486486
# accuracy                0.512821
# macro avg               0.511536
# weighted avg            0.517317
#  4 _ 1 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.529412  0.352941      0.587755            0.250000
# 1.0           0.636364  0.500000      0.476684            0.478261
# accuracy      0.589744  0.435897      0.538813            0.384615
# macro avg     0.582888  0.426471      0.532220            0.364130
# weighted avg  0.570547  0.409502      0.532980            0.337793
#
#               f1-score_selected2
# 0.0                     0.500000
# 1.0                     0.473684
# accuracy                0.487179
# macro avg               0.486842
# weighted avg            0.489879
#  5 _ 1 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.450000  0.368421      0.594796            0.615385
# 1.0           0.421053  0.400000      0.355030            0.615385
# accuracy      0.435897  0.384615      0.502283            0.615385
# macro avg     0.435526  0.384211      0.474913            0.615385
# weighted avg  0.438866  0.380567      0.476555            0.615385
#
#               f1-score_selected2
# 0.0                     0.473684
# 1.0                     0.500000
# accuracy                0.487179
# macro avg               0.486842
# weighted avg            0.483806
#  1 _ 2 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.550000  0.473684      0.425121            0.421053
# 1.0           0.526316  0.500000      0.484848            0.450000
# accuracy      0.538462  0.487179      0.456621            0.435897
# macro avg     0.538158  0.486842      0.454985            0.435526
# weighted avg  0.540891  0.483806      0.454576            0.432186
#
#               f1-score_selected2
# 0.0                     0.137931
# 1.0                     0.489796
# accuracy                0.358974
# macro avg               0.313863
# weighted avg            0.273264
#  1 _ 4 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.578947  0.432432      0.425121            0.375000
# 1.0           0.600000  0.487805      0.484848            0.565217
# accuracy      0.589744  0.461538      0.456621            0.487179
# macro avg     0.589474  0.460119      0.454985            0.470109
# weighted avg  0.587045  0.453730      0.454576            0.448161
#
#               f1-score_selected2
# 0.0                     0.514286
# 1.0                     0.604651
# accuracy                0.564103
# macro avg               0.559468
# weighted avg            0.549042
#  3 _ 1 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.550000  0.432432      0.425121            0.275862
# 1.0           0.526316  0.487805      0.484848            0.571429
# accuracy      0.538462  0.461538      0.456621            0.461538
# macro avg     0.538158  0.460119      0.454985            0.423645
# weighted avg  0.540891  0.453730      0.454576            0.389541
#
#               f1-score_selected2
# 0.0                     0.514286
# 1.0                     0.604651
# accuracy                0.564103
# macro avg               0.559468
# weighted avg            0.549042
#  2 _ 1 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.487805  0.470588      0.676829            0.571429
# 1.0           0.432432  0.590909      0.036364            0.500000
# accuracy      0.461538  0.538462      0.515982            0.538462
# macro avg     0.460119  0.530749      0.356596            0.535714
# weighted avg  0.466508  0.516865      0.360983            0.543956
#
#               f1-score_selected2
# 0.0                     0.473684
# 1.0                     0.500000
# accuracy                0.487179
# macro avg               0.486842
# weighted avg            0.483806
#  2 _ 2 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.473684  0.723404      0.676829            0.615385
# 1.0           0.500000  0.580645      0.036364            0.615385
# accuracy      0.487179  0.666667      0.515982            0.615385
# macro avg     0.486842  0.652025      0.356596            0.615385
# weighted avg  0.483806  0.668497      0.360983            0.615385
#
#               f1-score_selected2
# 0.0                     0.375000
# 1.0                     0.565217
# accuracy                0.487179
# macro avg               0.470109
# weighted avg            0.448161
#  3 _ 2 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.444444  0.473684      0.425121            0.487805
# 1.0           0.523810  0.500000      0.484848            0.432432
# accuracy      0.487179  0.487179      0.456621            0.461538
# macro avg     0.484127  0.486842      0.454985            0.460119
# weighted avg  0.474969  0.483806      0.454576            0.466508
#
#               f1-score_selected2
# 0.0                     0.388889
# 1.0                     0.476190
# accuracy                0.435897
# macro avg               0.432540
# weighted avg            0.422466
#  4 _ 4 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.444444  0.651163      0.529412            0.604651
# 1.0           0.523810  0.571429      0.440000            0.514286
# accuracy      0.487179  0.615385      0.488584            0.564103
# macro avg     0.484127  0.611296      0.484706            0.559468
# weighted avg  0.474969  0.620496      0.485318            0.569895
#
#               f1-score_selected2
# 0.0                     0.486486
# 1.0                     0.536585
# accuracy                0.512821
# macro avg               0.511536
# weighted avg            0.505755
#  5 _ 4 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.615385  0.473684      0.347305            0.500000
# 1.0           0.615385  0.500000      0.597786            0.473684
# accuracy      0.615385  0.487179      0.502283            0.487179
# macro avg     0.615385  0.486842      0.472546            0.486842
# weighted avg  0.615385  0.483806      0.470830            0.489879
#
#               f1-score_selected2
# 0.0                     0.578947
# 1.0                     0.600000
# accuracy                0.589744
# macro avg               0.589474
# weighted avg            0.587045
#  2 _ 3 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.461538  0.651163      0.668693            0.711111
# 1.0           0.461538  0.571429      0.000000            0.606061
# accuracy      0.461538  0.615385      0.502283            0.666667
# macro avg     0.461538  0.611296      0.334347            0.658586
# weighted avg  0.461538  0.620496      0.338927            0.670707
#
#               f1-score_selected2
# 0.0                     0.470588
# 1.0                     0.590909
# accuracy                0.538462
# macro avg               0.530749
# weighted avg            0.516865
#  3 _ 3 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.294118  0.432432      0.425121            0.470588
# 1.0           0.454545  0.487805      0.484848            0.590909
# accuracy      0.384615  0.461538      0.456621            0.538462
# macro avg     0.374332  0.460119      0.454985            0.530749
# weighted avg  0.355821  0.453730      0.454576            0.516865
#
#               f1-score_selected2
# 0.0                     0.514286
# 1.0                     0.604651
# accuracy                0.564103
# macro avg               0.559468
# weighted avg            0.549042
#  1 _ 1 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.358974  0.432432      0.425121            0.275862
# 1.0           0.358974  0.487805      0.484848            0.571429
# accuracy      0.358974  0.461538      0.456621            0.461538
# macro avg     0.358974  0.460119      0.454985            0.423645
# weighted avg  0.358974  0.453730      0.454576            0.389541
#
#               f1-score_selected2
# 0.0                     0.514286
# 1.0                     0.604651
# accuracy                0.564103
# macro avg               0.559468
# weighted avg            0.549042
#  3 _ 4 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.600000  0.432432      0.425121            0.470588
# 1.0           0.578947  0.487805      0.484848            0.590909
# accuracy      0.589744  0.461538      0.456621            0.538462
# macro avg     0.589474  0.460119      0.454985            0.530749
# weighted avg  0.591903  0.453730      0.454576            0.516865
#
#               f1-score_selected2
# 0.0                     0.470588
# 1.0                     0.590909
# accuracy                0.538462
# macro avg               0.530749
# weighted avg            0.516865
#  2 _ 4 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.583333  0.488889      0.668693            0.511628
# 1.0           0.333333  0.303030      0.000000            0.400000
# accuracy      0.487179  0.410256      0.502283            0.461538
# macro avg     0.458333  0.395960      0.334347            0.455814
# weighted avg  0.487179  0.417405      0.338927            0.468694
#
#               f1-score_selected2
# 0.0                     0.342857
# 1.0                     0.465116
# accuracy                0.410256
# macro avg               0.403987
# weighted avg            0.389880
#  5 _ 3 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.450000  0.521739      0.417112            0.421053
# 1.0           0.421053  0.312500      0.565737            0.450000
# accuracy      0.435897  0.435897      0.502283            0.435897
# macro avg     0.435526  0.417120      0.491425            0.435526
# weighted avg  0.438866  0.441263      0.490407            0.432186
#
#               f1-score_selected2
# 0.0                     0.333333
# 1.0                     0.583333
# accuracy                0.487179
# macro avg               0.458333
# weighted avg            0.429487
#  4 _ 3 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.312500  0.206897      0.380000            0.206897
# 1.0           0.521739  0.530612      0.478992            0.530612
# accuracy      0.435897  0.410256      0.433790            0.410256
# macro avg     0.417120  0.368754      0.429496            0.368754
# weighted avg  0.392977  0.331403      0.428818            0.331403
#
#               f1-score_selected2
# 0.0                     0.500000
# 1.0                     0.473684
# accuracy                0.487179
# macro avg               0.486842
# weighted avg            0.489879
#  5 _ 2 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.500000  0.342857      0.408163            0.638298
# 1.0           0.473684  0.465116      0.520661            0.451613
# accuracy      0.487179  0.410256      0.470320            0.564103
# macro avg     0.486842  0.403987      0.464412            0.544955
# weighted avg  0.489879  0.389880      0.463642            0.566496
#
#               f1-score_selected2
# 0.0                     0.486486
# 1.0                     0.536585
# accuracy                0.512821
# macro avg               0.511536
# weighted avg            0.505755
#  4 _ 2 .csv
#                  f1_RF    f1_All  f1-score_k-m  f1-score_selected1  \
# 0.0           0.457143  0.500000      0.364583            0.148148
# 1.0           0.558140  0.571429      0.504065            0.549020
# accuracy      0.512821  0.538462      0.442922            0.410256
# macro avg     0.507641  0.535714      0.434324            0.348584
# weighted avg  0.495988  0.527473      0.433369            0.302329
#
#               f1-score_selected2
# 0.0                     0.487805
# 1.0                     0.432432
# accuracy                0.461538
# macro avg               0.460119
# weighted avg            0.466508

# %%
for key in output_dic.keys():
    if key != '.csv':
        output_dic[key][1].to_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Report/feature selection table '+key)

# %%
for key in output_dic.keys():
    if key != '.csv':
        output_dic[key][3].to_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/Report/F1-score'+key)

# %%
# df1=pd.read_csv("/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/binary-data.csv")
# df2 = pd.read_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/metadata.csv')
# df1=df1.drop('Variety2',axis=1)
# df1.rename(columns={'Yield_per_plant':"y_binary"}, inplace=True)
# df2 = df2[['Unnamed: 0', 'Yield_per_plant']]
# df2.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)
# data_original = pd.merge(df1, df2, on='Link_ID')
# n_train=154
# cv=RepeatedKFold(n_splits=10,n_repeats=3, random_state=100)
# th=0.05
# NumofR=2
# q=0.7
# os.chdir('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data')
# path = '/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data'
# file_list = []
# for file in os.listdir(path):
#     if (file[0] != 'R') & (file[-4:] == '.csv'):
#         file_list.append(file[-4:]) 
# output_dic = dict.fromkeys(file_list)
# for file in os.listdir(path):
#     if file[-4:] == '.csv':
#         print(file)
#         data_temp = pd.read_csv(file)
#         output = process_data(data_original,data_temp,n_train,cv,q,NumofR)
#         output_dic[file] = [output[0],output[1], output[2],output[3]]

# %%
# df1=pd.read_csv("/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/binary-data.csv")
# df2 = pd.read_csv('/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/XUDONG/metadata.csv')
# df1=df1.drop('Variety2',axis=1)
# df1.rename(columns={'Yield_per_plant':"y_binary"}, inplace=True)
# df2 = df2[['Unnamed: 0', 'Yield_per_plant']]
# df2.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)
# data_original = pd.merge(df1, df2, on='Link_ID')
# n_train=154
# cv=RepeatedKFold(n_splits=10,n_repeats=3, random_state=100)
# th=0.05
# NumofR=2
# q=0.7
# path=os.chdir("/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data/")
# files = os.listdir(path)
# data=pd.read_csv("/Users/rosa/Desktop/ALLWork/Madison/Project/Soil-nn/DATA/Netcomi_data/ 1 _ 1 .csv")
# process_data(data_original,data,n_train,cv,q,NumofR)
# out = process_data(data_original,data,n_train,cv,q,NumofR)

# %%
# def process_data(data_original,data,n_train,cv,q,NumofR):
#     if 'Unnamed: 0' in data.columns:
#         data.rename(columns={'Unnamed: 0':'Link_ID'}, inplace=True)
#     data['y_binary']=data_original['y_binary'].values
#     data['Yield_per_plant']=data_original['Yield_per_plant'].values
#     fitted_y, fitted_lambda = stats.boxcox(data['Yield_per_plant'])
#     data['y_boxcox'] = fitted_y  
#     x_column_list = data.drop(columns=['Link_ID', 'y_binary', 'Yield_per_plant','y_boxcox']).columns
#     ###Split Data  
#     data_train = data.iloc[0:n_train]
#     data_val = data.iloc[n_train:]
#     y_b = 'y_binary'
#     y_c = 'Yield_per_plant'
#     y_c_boxcox = 'y_boxcox'
#     percent_label=[round(100*len(np.where(data_train[y_b]==0)[0])/len(data_train)),round(100*len(np.where(data_val[y_b]==0)[0])/len(data_val))]
#     #Feature Selection
#     feature_list1 = data[x_column_list].max().sort_values(ascending=False)[data[x_column_list].max()>np.quantile(data[x_column_list].max(),q)].index
#     #apply SelectKBest class to extract top 20 best features
#     bestfeatures = SelectKBest(score_func=mutual_info_regression, k=20)
#     fit = bestfeatures.fit(data[x_column_list],data[y_c])
#     dfscores = pd.DataFrame(fit.scores_)
#     dfcolumns = pd.DataFrame(x_column_list)
#     #concat two dataframes for better visualization 
#     featureScores = pd.concat([dfcolumns,dfscores],axis=1)
#     featureScores.columns = ['Variable','Score']  #naming the dataframe columns
#     feature_list2 = featureScores.nlargest(20,'Score')
#     feature_list3=stepwise_selection(data.drop(columns=
#                                 ['Link_ID', 'y_binary', 'Yield_per_plant', 'y_boxcox']),data[y_c])
#     reg = LassoCV(cv=cv).fit(data_train[x_column_list], data_train[y_c])
#     lassoCoefs0 = pd.DataFrame(
#     data=reg.coef_[np.where(reg.coef_ != 0)[0]], 
#     index=data[x_column_list].columns[np.where(reg.coef_ != 0)[0]],columns=['LASSO Coefs1'])
#     feature_list4=lassoCoefs0
    
#     parameters = {'n_estimators':(10,20,100, 500),
#                   'min_samples_split':(2,3,4),
#                   'min_samples_leaf':(1,2,3)}

#     gb_model = GradientBoostingRegressor(random_state=7, warm_start=False)
#     grid_obj = GridSearchCV(gb_model, param_grid=parameters, verbose=1, n_jobs=4, cv=cv)
#     grid_obj = grid_obj.fit(data_train[x_column_list],data_train[y_c])
#     gb_model_best = grid_obj.best_estimator_
#     y_hat = gb_model_best.predict(data_val[x_column_list])
#     FeatImportance = gb_model_best.feature_importances_
#     GBCoefs = pd.DataFrame(index=data_train[x_column_list].columns, data=FeatImportance,columns=['Coefs'])
#     imp_coef = GBCoefs.sort_values(by='Coefs')
#     feature_list6=imp_coef.loc[imp_coef['Coefs']>np.quantile(imp_coef,0.7)]
#     feature_list6 = [item for item in feature_list6.index]
#     rf_model = RandomForestRegressor(warm_start=False)
#     grid_obj = GridSearchCV(rf_model, param_grid=parameters, verbose=1, n_jobs=4, cv=cv)
#     grid_obj = grid_obj.fit(data_train[x_column_list],data_train[y_c])
#     rf_model_best = grid_obj.best_estimator_
#     y_hat_rf = rf_model_best.predict(data_val[x_column_list])  
#     rf_model_best.score(data_val[x_column_list],data_val[y_c])
#     FeatImportance = rf_model_best.feature_importances_
#     RFCoefs = pd.DataFrame(index=data_train[x_column_list].columns, data=FeatImportance,columns=['Coefs'])
#     imp_coef_RF = RFCoefs.sort_values(by='Coefs')
#     feature_list7=imp_coef_RF.loc[imp_coef_RF['Coefs']>np.quantile(imp_coef_RF,0.7)]
#     feature_list7 = [item for item in feature_list7.index]
    
#     mi = mutual_info_regression(data_train[x_column_list],data_train[y_c], discrete_features=False, n_neighbors=3, copy=True, random_state=None)
#     MI=pd.DataFrame(mi)
#     MI['OTU']=data[x_column_list].columns
#     MI=MI.set_index('OTU')
#     MI=MI.sort_values(0,ascending=False)
#     feature_list8=MI[MI[0]>np.quantile(mi,q)].index
    
#     methodList = ['Maximum', 
#               'KBest', 
#               'Stepwise Regression', 
#               'Lasso CV', 
#               'GBM', 
#               'Random Forest', 
#               'Mutual Info']
#     featureList = [[item for item in feature_list1], 
#                [item for item in feature_list2['Variable'].values], 
#                feature_list3, 
#                [item for item in feature_list4.index], 
#                feature_list6, 
#                feature_list7,
#                [item for item in feature_list8]]
#     featureUniqueList = np.unique([item for sublist in featureList for item in sublist])
#     featureDictionary = dict.fromkeys(featureUniqueList)
#     for key in featureDictionary.keys():
#         featureDictionary[key] = []
    

#     for feature in featureUniqueList:
    
#         for i, method in enumerate(methodList):
        
#             if feature in featureList[i]:
#                 featureDictionary[feature].append(method)   

#     featureDf = pd.DataFrame(index=featureUniqueList, columns=methodList)
#     featureDf['Count'] = 0

#     for feature in featureDictionary.keys(): 
#         for method in methodList:
        
#             if method in featureDictionary[feature]:
            
#                 featureDf['Count'][feature] += 1
            
#                 featureDf[method][feature] = 'X'
#             else:
#                 featureDf[method][feature] = '-' 
#     featureDf.sort_values(by='Count', ascending=False, inplace=True)

#     #Classification RF
#     pipeRF = Pipeline([('classifier', [RandomForestClassifier()])])
#     param_grid = [
#     {'classifier' : [RandomForestClassifier()],
#     'classifier__criterion':('gini','entropy'),
#     'classifier__class_weight':('balanced','auto')}]
#     clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')

#     # Fit on data
#     clf.fit(data_train[x_column_list],data_train[y_b])
#     best_clf=clf.best_estimator_
#     y_valid=best_clf.predict(data_val[x_column_list])
#     matrix = confusion_matrix(data_val[y_b], y_valid)
#     report_RF = classification_report(data_val[y_b],y_valid,output_dict=True)
#     dRF = pd.DataFrame(report_RF).transpose()
#     #Classification All Model
#     pipe = Pipeline([('classifier', [RandomForestClassifier(),DecisionTreeClassifier(),SGDClassifier(),SVC(),KNeighborsClassifier()])])
#     param_grid = [
#     {'classifier' : [RandomForestClassifier()]},   
#     {'classifier' : [DecisionTreeClassifier()]}, 
#     #{'classifier' : [SGDClassifier()]},
#     {'classifier' : [SVC()],      
#     'classifier__class_weight':('balanced','auto'),
#     'classifier__gamma' : [1,0.1,0.01,0.001]},
#     #'classifier__ kernel': ['rbf', 'poly', 'sigmoid']},
#     {'classifier' : [KNeighborsClassifier()],
#      'classifier__n_neighbors':list(range(5,25))} ]
#     clf = GridSearchCV(pipe, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#     # Fit on data
#     clf.fit(data_train[x_column_list],data_train[y_b])
#     best_clf=clf.best_estimator_
#     y_valid=best_clf.predict(data_val[x_column_list])
#     report_All = classification_report(data_val[y_b],y_valid,output_dict=True)
#     dAll=pd.DataFrame(report_All).transpose()
#     #Classification by selected feature
#     selected_features = featureDf[featureDf['Count']>2].index
    
#     clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#     # Fit on data
#     clf.fit(data_train[selected_features],data_train[y_b])
#     best_clf=clf.best_estimator_
#     y_valid=best_clf.predict(data_val[selected_features])
#     report_selected = classification_report(data_val[y_b],y_valid,output_dict=True)
#     dfselected1=pd.DataFrame(report_selected).transpose()



#     ### from original data and selected features
#     new_column_list = [col.replace('.','-') for col in selected_features]
#     clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#     # Fit on data
#     clf.fit(data_original[new_column_list].div(data_original[new_column_list].sum(axis=1), axis=0)[0:len(data_train[y_b])],data_train[y_b])
#     best_clf=clf.best_estimator_
#     y_valid=best_clf.predict(data_original[new_column_list].div(data_original[new_column_list].sum(axis=1), axis=0)[len(data_train[y_b]):])
#     report_selected2 = classification_report(data_val[y_b],y_valid,output_dict=True)
#     dfselected2=pd.DataFrame(report_selected2).transpose()
#     dfselected=pd.merge(dfselected1,dfselected2,on=dfselected2.index)

#     #Clustering
#     kmeans = KMeans(n_clusters=2, random_state=0).fit(data[x_column_list])
#     report_k_means= classification_report(data[y_b],kmeans.labels_,output_dict=True)
#     dK_means=pd.DataFrame(report_k_means).transpose()
#     dK_means['key_0']=dK_means.index
#     c_1=pd.merge(dRF,dAll,on=dRF.index)
#     c_2=pd.merge(c_1,dK_means,on='key_0')
#     c_3=pd.merge(c_2,dfselected,on='key_0')
#     coln=['class','precision_RF','recall_RF','f1_RF','support_RF','precision_All','recall_All','f1_All','support_All','precision_k-m','recall_k-m','f1-score_k-m','support_k-m','precision_selected1','recall_selected1','f1-score_selected1','support_selected1','precision_selected2','recall_selected2','f1-score_selected2','support_selected2']
#     c_3.columns=coln
#     #####conclusion
#     f1_cols = [col for col in c_3.columns if 'f1' in col]
#     c_f1_t=c_3[f1_cols]
#     c_f1=pd.DataFrame(c_f1_t.iloc[4,:])
#     c_f1.rename(columns={4:'f1'}, inplace=True)
#     namemethod=c_f1['f1'].idxmax()
#     f_0=c_f1_t[namemethod][0]
#     f_1=c_f1_t[namemethod][1]
#     BestF=[f_0,f_1]
#     F1_0_class_RF=c_3.iloc[0,3]
#     F1_1_class_RF=c_3.iloc[1,3]
#     #Comparing to random
#     #senario1
#     totalF1_0=[]
#     totalF1_1=[]
#     for i in range(1,NumofR):
#         RD1= np.random.rand(data[x_column_list].shape[0],data[x_column_list].shape[1])
#         RD1=pd.DataFrame(RD1)
#         RD1.columns =data[x_column_list].columns
#         RD11=RD1.div(RD1.sum(axis=1), axis=0)
#         RD11['y_b']=data[y_b]
#         RD11['y_c']=data[y_c]
#         clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#         clf.fit(RD11.iloc[0:n_train,0:len(x_column_list)], RD11['y_b'][0:n_train])
#         best_clf=clf.best_estimator_
#         y_valid=best_clf.predict(RD11.iloc[n_train:,0:len(x_column_list)])
#         report_Random = classification_report(RD11['y_b'][n_train:],y_valid,output_dict=True)
#         totalF1_0.append(report_Random ['0.0']['f1-score'])
#         totalF1_1.append(report_Random ['1.0']['f1-score'])    
#     r=pd.DataFrame()
#     r['0']= totalF1_0
#     r['1']= totalF1_1
#     EV1=r[(r['0'] >= F1_0_class_RF) & (r['1'] >=F1_1_class_RF)].shape[0]/ NumofR
#     #senario2
#     totalF1_0_2=[]
#     totalF1_1_2=[]
#     #weightedF1_RF,F1_0_class_RF,F1_1_class_RF
#     for i in range(1,NumofR):
#         RD2=pd.DataFrame(np.random.rand(data[x_column_list].shape[0],data[x_column_list].shape[1]))
#         RD2.columns=data[x_column_list].columns
#         for col in data[x_column_list].columns:
#             dd=np.where(data[x_column_list][col]==0)[0]
#             if len(dd)>0:
#                 RD2[col][dd]=0
#         RD22=RD2.div(RD2.sum(axis=1), axis=0)
#         RD22['y_b']=data[y_b].values
#         RD22['y_c']=data[y_c].values
#         clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#         clf.fit(RD22[x_column_list][0:n_train], RD22['y_b'][0:n_train])
#         best_clf=clf.best_estimator_
#         y_valid=best_clf.predict(RD22[x_column_list][n_train:])
#         report_Random2 = classification_report(RD22['y_b'][n_train:],y_valid,output_dict=True)
#         totalF1_0_2.append(report_Random2['0.0']['f1-score'])
#         totalF1_1_2.append(report_Random2['1.0']['f1-score'])
#     r2=pd.DataFrame()
#     r2['0']= totalF1_0_2
#     r2['1']= totalF1_1_2
#     EV2=r2[(r2['0'] >= F1_0_class_RF) & (r2['1'] >=F1_1_class_RF)].shape[0]/ NumofR
#     #senario3
#     totalF1_0_3=[]
#     totalF1_1_3=[]
#     #weightedF1_RF,F1_0_class_RF,F1_1_class_RF
#     for i in range(1,NumofR):
#         YR=np.random.permutation(data['y_binary'].values)
#         clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#         clf.fit(data[x_column_list][0:n_train],  YR[0:n_train])
#         best_clf=clf.best_estimator_
#         y_valid=best_clf.predict(data[x_column_list][n_train:])
#         report_Random2 = classification_report(YR[n_train:],y_valid,output_dict=True)
#         totalF1_0_3.append(report_Random2['0.0']['f1-score'])
#         totalF1_1_3.append(report_Random2['1.0']['f1-score'])
#     r3=pd.DataFrame()
#     r3['0']= totalF1_0_3
#     r3['1']= totalF1_1_3
#     EV3=r3[(r3['0'] >= F1_0_class_RF) & (r3['1'] >=F1_1_class_RF)].shape[0]/ NumofR
#     #Senario4
#     totalF1_0_4=[]
#     totalF1_1_4=[]
#     for i in range(1,NumofR):
#         DR=data[x_column_list].sample(frac=1)
#         clf = GridSearchCV(pipeRF, param_grid = param_grid, cv = cv, n_jobs=-1, scoring='f1_weighted')
#         clf.fit(DR[0:n_train],  data['y_binary'][0:n_train])
#         best_clf=clf.best_estimator_
#         y_valid=best_clf.predict(DR[n_train:])
#         report_Random2 = classification_report(data['y_binary'][n_train:],y_valid,output_dict=True)
#         totalF1_0_4.append(report_Random2['0.0']['f1-score'])
#         totalF1_1_4.append(report_Random2['1.0']['f1-score'])
#     r4=pd.DataFrame()
#     r4['0']= totalF1_0_4
#     r4['1']= totalF1_1_4
#     EV4=r4[(r4['0'] >= F1_0_class_RF) & (r4['1'] >=F1_1_class_RF)].shape[0]/ NumofR
#     ev_value=[EV1,EV2,EV3,EV4]
#     return percent_label,featureDf, c_3,c_f1_t, r,r2,r3,ev_value
#     #return percent_label
